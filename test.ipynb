# %%
#autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %load_ext autoreload
# %autoreload 2

# %%
from simulations import queue_sim
from simulated_metrics import customers_dist
from plot_metrics import plot_md1_customers_dist
import pandas as pd

# %%
sim = queue_sim(lamda= .3, mu = .2, runs = 1000, max_events= 100)

# %%
sim.plot_customers(figsize= (25,5), max_ticks = 10)
# Out:
#          pdf                                         pdf_CI       cdf  \
# N
# 0   0.048440     (0.04497355400221918, 0.05190684816771038)  0.048440
# 1   0.047368    (0.04455933851897507, 0.050176693957522535)  0.079096
# 2   0.047992     (0.04528525463169078, 0.05069855255978334)  0.127088
# 3   0.048748    (0.045939049141045844, 0.05155684959667923)  0.175836
# 4   0.047949     (0.0452347148931529, 0.050663209729045304)  0.223785
# 5   0.046493    (0.043737169360472714, 0.04924813129854319)  0.270278
# 6   0.045256     (0.04276514403302932, 0.04774694092349678)  0.315534
# 7   0.048617     (0.04587583144151728, 0.05135843860188482)  0.364102
# 8   0.046783      (0.04411585421037738, 0.0494500446784817)  0.410651
# 9   0.045135    (0.042579380431522415, 0.04769059290396607)  0.455425
# 10  0.042879    (0.04039743992776749, 0.045359913713521084)  0.497575
# 11  0.041609    (0.03920533541550523, 0.044012514425722675)  0.537852
# ...

# %%
from plot_metrics import plot_mm1_wait_dist
from simulations import queue_sim
from simulated_metrics import wait_dist
sim = queue_sim(lamda= 4, mu = 2, max_events = 1e1000, runs = 10000)
dist_df = plot_mm1_wait_dist(sim)
# Out:
#           0         1         2         3         4         5         6     \
# 0     0.037569  0.636612  1.343644  2.427046  2.353807  2.356768  2.419216
# 1     0.566704  0.718989  1.421431  2.660348  1.526769  2.136291  2.049109
# 2     0.394047  0.140030  0.997861  2.040442  2.506288  3.265489  3.260948
# 3     1.304541  1.945237  1.965032  2.175366  1.880719  2.736967  2.693027
# 4     2.167024  2.337176  2.448167  2.525672  3.998405  3.831739  4.147098
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.479902  0.904905  1.540435  2.318399  3.117620  3.129541  3.881373
# 9996  0.214129  0.013742  0.740629  0.726592  0.739137  1.934465  2.479807
# 9997  0.480286  0.705389  1.163376  0.900537  0.943589  1.301709  1.830518
# 9998  0.302625  0.304180  0.389031  0.517973  0.527407  0.807833  0.844582
# 9999  0.043793  0.483594  1.215475  0.970905  1.412372  1.372175  1.491921
#
# ...
