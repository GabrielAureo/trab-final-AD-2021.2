# %%
#autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %load_ext autoreload
# %autoreload 2

# %%
from simulations import queue_sim
from simulated_metrics import customers_dist
from plot_metrics import plot_md1_customers_dist
import pandas as pd

# %%
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', None)

# %%
sim = queue_sim(lamda= 1, mu = 10, runs = 10, max_events= 100)

# %%
sim.plot_customers(figsize= (25,5))
# Out:
#         pdf                                          pdf_CI       cdf  \
# N
# 0  0.901646        (0.8913430406848459, 0.9119483817191913)  0.901646
# 1  0.087786       (0.08025289108019289, 0.0953189688992392)  0.989432
# 2  0.010831    (0.006208357936892011, 0.015454082075692719)  0.999180
# 3  0.002051  (0.0005036732527099752, 0.0035976307603008562)  1.000000
#
#                                      cdf_CI
# N
# 0  (0.8913430406848459, 0.9119483817191913)
# 1  (0.9846524622684838, 0.9942108201149857)
# 2  (0.9983163213513252, 1.0000431570434707)
# 3                 (0.9999999999999999, 1.0)

# %%
from plot_metrics import plot_mm1_wait_dist
dist_df = plot_mm1_wait_dist(sim)
# Out:
#                                                     pdf  \
# cut
# (0.0021569475780480367, 0.048510364359964066)  0.078892
# (0.048510364359964066, 0.09486378114188009)    0.181795
# (0.09486378114188009, 0.14121719792379614)     0.162692
# (0.14121719792379614, 0.18757061470571215)     0.144939
# (0.18757061470571215, 0.23392403148762816)     0.169916
# (0.23392403148762816, 0.2802774482695442)      0.125993
# (0.2802774482695442, 0.3266308650514602)       0.160813
# (0.3266308650514602, 0.37298428183337623)      0.119648
# (0.37298428183337623, 0.41933769861529224)     0.107820
#
#                                                                                    pdf_CI  \
# cut
# (0.0021569475780480367, 0.048510364359964066)   (0.0665225715722074, 0.09126241601833476)
# (0.048510364359964066, 0.09486378114188009)    (0.13691498167776087, 0.22667564970592283)
# (0.09486378114188009, 0.14121719792379614)      (0.13852775671152578, 0.1868570158993113)
# (0.14121719792379614, 0.18757061470571215)      (0.09252971258106846, 0.1973482722977683)
# (0.18757061470571215, 0.23392403148762816)     (0.12268774721815279, 0.21714406836639522)
# (0.23392403148762816, 0.2802774482695442)      (0.08239155317706326, 0.16959466374601867)
# (0.2802774482695442, 0.3266308650514602)       (0.10614117173643059, 0.21548429151959006)
# (0.3266308650514602, 0.37298428183337623)      (0.05694427506371623, 0.18235183998847004)
# (0.37298428183337623, 0.41933769861529224)     (0.04806675992531668, 0.16757414548426827)
#
#                                                     cdf  \
# cut
# (0.0021569475780480367, 0.048510364359964066)  0.078892
# (0.048510364359964066, 0.09486378114188009)    0.260688
# (0.09486378114188009, 0.14121719792379614)     0.423380
# (0.14121719792379614, 0.18757061470571215)     0.568319
# (0.18757061470571215, 0.23392403148762816)     0.734500
# (0.23392403148762816, 0.2802774482695442)      0.847237
# (0.2802774482695442, 0.3266308650514602)       0.920180
# (0.3266308650514602, 0.37298428183337623)      1.000000
# (0.37298428183337623, 0.41933769861529224)     1.000000
#
#                                                                                    cdf_CI
# cut
# (0.0021569475780480367, 0.048510364359964066)   (0.0665225715722074, 0.09126241601833476)
# (0.048510364359964066, 0.09486378114188009)    (0.21618044896616545, 0.30519517000806035)
# (0.09486378114188009, 0.14121719792379614)     (0.37251082458847856, 0.47424956699658444)
# (0.14121719792379614, 0.18757061470571215)       (0.5058133675173029, 0.6308250089465968)
# (0.18757061470571215, 0.23392403148762816)       (0.6459395948291711, 0.8230598639058408)
# (0.23392403148762816, 0.2802774482695442)        (0.7641102161398905, 0.9303630112731844)
# (0.2802774482695442, 0.3266308650514602)          (0.8628260262227263, 0.977534766230278)
# (0.3266308650514602, 0.37298428183337623)                                      (1.0, 1.0)
# (0.37298428183337623, 0.41933769861529224)                                     (1.0, 1.0)
