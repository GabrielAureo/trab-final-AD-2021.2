# %%
#autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %load_ext autoreload
# %autoreload 2

# %%
from simulations import queue_sim
from simulated_metrics import customers_dist
from plot_metrics import plot_md1_customers_dist
import pandas as pd

# %%
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', None)

# %%
sim = queue_sim(lamda= .3, mu = .2, runs = 1000, max_events= 100)

# %%
sim.plot_customers(figsize= (25,5))
# Out:
#          pdf                                          pdf_CI       cdf  \
# N
# 0   0.049717    (0.046147849261479544, 0.053285190222714864)  0.049717
# 1   0.050511     (0.04756905904484146, 0.053453613666615746)  0.084617
# 2   0.048882       (0.0461319973417253, 0.05163256322061859)  0.133499
# 3   0.049826     (0.04695733485860082, 0.052693921428785734)  0.183325
# 4   0.049846     (0.04697166118882614, 0.052720063902903826)  0.233171
# 5   0.049941      (0.04703225543276642, 0.05284995669066137)  0.283112
# 6   0.049062     (0.04629482022394601, 0.051828899709872124)  0.332174
# 7   0.046965     (0.04432665578611919, 0.049604274478922336)  0.378998
# 8   0.045894      (0.04331050162287711, 0.04847775932265559)  0.424571
# 9   0.043701      (0.04130159166960129, 0.04610012547430685)  0.467616
# 10  0.042225      (0.03980329775904152, 0.04464618949636382)  0.508743
# 11  0.043264     (0.040614515637403426, 0.04591288558565802)  0.550276
# 12  0.041754       (0.0392545344911692, 0.04425422880075034)  0.589233
# 13  0.041446      (0.03885902952822396, 0.04403338058167127)  0.627157
# 14  0.039963     (0.03751355617237182, 0.042413394374468096)  0.662205
# 15  0.038471      (0.03604793765822805, 0.04089472137884705)  0.694905
# 16  0.037012      (0.03470845545287061, 0.03931618157861986)  0.725033
# 17  0.036822      (0.03444383287832934, 0.03920100997765096)  0.753828
# 18  0.036609    (0.034223844655636465, 0.038995077660958735)  0.781176
# 19  0.036357     (0.03390244133430758, 0.038811256340902205)  0.807243
# 20  0.035415      (0.03300693649833015, 0.03782243193451005)  0.831113
# 21  0.034921     (0.03238660820362467, 0.037455196640576505)  0.853288
# 22  0.033830     (0.03128327331659927, 0.036377065823244355)  0.873248
# 23  0.032693     (0.03011117109064171, 0.035275517311307195)  0.891196
# 24  0.029821    (0.027278776151058184, 0.032362606361051156)  0.905808
# 25  0.027333     (0.024816823447342398, 0.02984868984025191)  0.917999
# 26  0.028635     (0.026077910315245072, 0.03119231013854418)  0.929281
# 27  0.029238    (0.026347242790210623, 0.032129213148889176)  0.939894
# 28  0.031354     (0.02818652148559088, 0.034522151025807704)  0.949834
# 29  0.027415    (0.024804360369886022, 0.030024659726136826)  0.957702
# 30  0.028883    (0.025797446947287687, 0.031968803235387915)  0.964778
# 31  0.028209    (0.025023156272272102, 0.031394139835383965)  0.971097
# 32  0.029436      (0.02491536845533254, 0.03395762245098488)  0.976896
# 33  0.028454    (0.023852665457269516, 0.033055792823989315)  0.981790
# 34  0.026625     (0.022453338026648985, 0.03079568180547175)  0.985464
# 35  0.026191    (0.021858087357137623, 0.030524632378358826)  0.988607
# 36      (0.9886718533641247, 0.9935588039424493)
# 37      (0.9912056725691588, 0.9953133163066995)
# 38      (0.9932331208163563, 0.9966478317364851)
# 39      (0.9951102604045285, 0.9978950311402959)
# 40      (0.9961782235126112, 0.9985445257495175)
# 41      (0.9971740360874185, 0.9991129949913463)
# 42       (0.9977980230098523, 0.999445201731462)
# 43      (0.9983622401475383, 0.9996533024270557)
# 44      (0.9987801803907621, 0.9998220547123393)
# 45      (0.9991745198643831, 0.9999687489358007)
# 46        (0.9994140873860355, 1.00004994970132)
# 47      (0.9996766753160138, 1.0000587673531176)
# 48      (0.9998047556683949, 1.0000628752932288)
# N
# 0     0.049717
# 1     0.050511
# 2     0.048882
# 3     0.049826
# 4     0.049846
# 5     0.049941
# 6     0.049062
# 7     0.046965
# 8     0.045894
# 9     0.043701
# 10    0.042225
# 11    0.043264
# 12    0.041754
# 13    0.041446
# 14    0.039963
# 15    0.038471
# 16    0.037012
# 17    0.036822
# 18    0.036609
# 19    0.036357
# 20    0.035415
# 21    0.034921
# 22    0.033830
# 23    0.032693
# 24    0.029821
# 25    0.027333
# 26    0.028635
# 27    0.029238
# 28    0.031354
# 29    0.027415
# 30    0.028883
# 31    0.028209
# 32    0.029436
# 33    0.028454
# 34    0.026625
# 35    0.026191
# 36    0.027264
# 37    0.025833
# 38    0.024720
# 39    0.027896
# 40    0.022019
# 41    0.023701
# 42    0.019124
# 43    0.017553
# 44    0.019556
# 45    0.022543
# 46    0.020048
# 47    0.016963
# 48    0.016524
# Name: pdf, dtype: float64
# aqui 2
# False
# N
# 0     0.049717
# 1     0.084617
# 2     0.133499
# 3     0.183325
# 4     0.233171
# 5     0.283112
# 6     0.332174
# 7     0.378998
# 8     0.424571
# 9     0.467616
# 10    0.508743
# 11    0.550276
# 12    0.589233
# 13    0.627157
# 14    0.662205
# 15    0.694905
# 16    0.725033
# 17    0.753828
# 18    0.781176
# 19    0.807243
# 20    0.831113
# 21    0.853288
# 22    0.873248
# 23    0.891196
# 24    0.905808
# 25    0.917999
# 26    0.929281
# 27    0.939894
# 28    0.949834
# 29    0.957702
# 30    0.964778
# 31    0.971097
# 32    0.976896
# 33    0.981790
# 34    0.985464
# 35    0.988607
# 36    0.991115
# 37    0.993259
# 38    0.994940
# 39    0.996503
# 40    0.997361
# 41    0.998144
# 42    0.998622
# 43    0.999008
# 44    0.999301
# 45    0.999572
# 46    0.999732
# 47    0.999868
# 48    0.999934
# Name: cdf, dtype: float64
# aqui 2
# False

# %%
from plot_metrics import plot_mm1_wait_dist
from simulations import queue_sim
sim = queue_sim(lamda= 1, mu = 10)
dist_df = plot_mm1_wait_dist(sim)
# Out:
# 0.000238    0.149774
# 0.074373    0.246007
# 0.148508    0.210388
# 0.222642    0.157094
# 0.296777    0.100009
# 0.370912    0.058422
# 0.445046    0.042131
# 0.519181    0.022478
# 0.593315    0.015219
# Name: pdf, dtype: float64
# aqui 2
# False
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\aluno08.TSACBRRJLP044\Documents\GitHub\trab-final-AD-2021.2\test.ipynb Cell 6' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/test.ipynb#ch0000005?line=1'>2</a> from simulations import queue_sim
#       <a href='vscode-notebook-cell:/c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/test.ipynb#ch0000005?line=2'>3</a> sim = queue_sim(lamda= 1, mu = 10)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/test.ipynb#ch0000005?line=3'>4</a> dist_df = plot_mm1_wait_dist(sim)
#
# File c:\Users\aluno08.TSACBRRJLP044\Documents\GitHub\trab-final-AD-2021.2\plot_metrics.py:115, in plot_mm1_wait_dist(simulation_obj, figsize, **kwargs)
#     <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=110'>111</a> _kwargs = {
#     <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=111'>112</a>     'x_label' : 'mean_wait'
#     <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=112'>113</a> }
#     <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=113'>114</a> kwargs.update(_kwargs)
# --> <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=114'>115</a> _plot_pdf(waits, None, plot_analytical = False, figsize= figsize, **kwargs)
#     <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=115'>116</a> return waits
#
# File c:\Users\aluno08.TSACBRRJLP044\Documents\GitHub\trab-final-AD-2021.2\plot_metrics.py:60, in _plot_pdf(simulated_distributions, analytical_pdf, plot_analytical, figsize, **kwargs)
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=53'>54</a> _kwargs = {
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=54'>55</a>     'simulated_label' : 'simulated pdf',
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=55'>56</a>     'analytical_label' : 'analytical pdf',
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=56'>57</a>     'y_label' : 'pdf'
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=57'>58</a> }
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=58'>59</a> kwargs.update(_kwargs)
# ---> <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=59'>60</a> _plot(simulated_distributions['pdf'], simulated_distributions['pdf_CI'], analytical_pdf, plot_analytical= plot_analytical, figsize= figsize, **kwargs)
#
# File c:\Users\aluno08.TSACBRRJLP044\Documents\GitHub\trab-final-AD-2021.2\plot_metrics.py:43, in _plot(simulated, CI, analytical, figsize, plot_analytical, **kwargs)
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=40'>41</a> total_ticks = int(total_ticks) + 1
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=41'>42</a> #ax.set_xticks( np.linspace(0, ticks_dist * total_ticks , total_ticks + 1, dtype = int ))
# ---> <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=42'>43</a> ax.set_xticks = ( [bisect.bisect_left(simulated.index, i) for i in [x + ticks_dist for _ in range(total_ticks)] ] )
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=43'>44</a> ax.set_xticklabels(ax.get_xticks(), rotation = 90)
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=45'>46</a> ax.set_yticks(np.linspace(0, max_y , 11 ))
#
# File c:\Users\aluno08.TSACBRRJLP044\Documents\GitHub\trab-final-AD-2021.2\plot_metrics.py:43, in <listcomp>(.0)
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=40'>41</a> total_ticks = int(total_ticks) + 1
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=41'>42</a> #ax.set_xticks( np.linspace(0, ticks_dist * total_ticks , total_ticks + 1, dtype = int ))
# ---> <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=42'>43</a> ax.set_xticks = ( [bisect.bisect_left(simulated.index, i) for i in [x + ticks_dist for _ in range(total_ticks)] ] )
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=43'>44</a> ax.set_xticklabels(ax.get_xticks(), rotation = 90)
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/plot_metrics.py?line=45'>46</a> ax.set_yticks(np.linspace(0, max_y , 11 ))
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
