# %%
#autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from simulations import queue_sim
from simulated_metrics import customers_dist, metrics
from analytical import dtmc_stationary_distribution
from plot_metrics import plot_mm1_customers_dist, plot_md1_customers_dist
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## M/D/1: $\rho$ = 0.1, $\lambda$ = 1, $\mu$ = 10

# %%
sim = queue_sim(lamda = 1, mu = 10, runs = 100, kind='d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\gabri\Documents\trab-final-AD-2021.2\md1.ipynb Cell 4' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gabri/Documents/trab-final-AD-2021.2/md1.ipynb#ch0000003?line=0'>1</a> sim = queue_sim(lamda = 1, mu = 10, runs = 100, kind='d')
#
# NameError: name 'queue_sim' is not defined

# %%
sim.service_durations
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\gabri\Documents\trab-final-AD-2021.2\md1.ipynb Cell 5' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gabri/Documents/trab-final-AD-2021.2/md1.ipynb#ch0000004?line=0'>1</a> sim.service_durations
#
# NameError: name 'sim' is not defined

# %%
dist = customers_dist(sim)
display(dist)
plot_pdf(dist, sim.lamda, sim.mu, kind = 'd')
plot_cdf(dist, sim.lamda, sim.mu, kind = 'd')
# Out:
#         pdf       cdf
# N
# 0  0.900069  0.900069
# 1  0.094623  0.994692
# 2  0.005091  0.999783
# 3  0.000208  0.999991
# 4  0.000009  1.000000

# %%
metrics(sim)
# Out:
#                                                                           Metrics
# Wait              Simulated                                               0.10553
#                   Confidence Interval   (0.1053264866437225, 0.10573397362037755)
#                   Analytical                                             0.105531
# Average Customers Simulated                                              0.105746
#                   Confidence Interval   (0.10467590593452582, 0.1068165395973298)
#                   Analytical                                             0.105531
# Utilization       Simulated                                              0.100164
#                   Confidence Interval  (0.09922750296536251, 0.10110148341120814)
#                   Analytical                                             0.099994

# %%
sim = queue_sim(lamda = 5, mu = 10, runs = 100, kind='d')

# %%
metrics(sim)
# Out:
#                                                                          Metrics
# Wait              Simulated                                             0.149241
#                   Confidence Interval  (0.14785204282271527, 0.1506293088719912)
#                   Analytical                                            0.149847
# Average Customers Simulated                                             0.742916
#                   Confidence Interval   (0.7304956638035358, 0.7553369076842558)
#                   Analytical                                            0.749234
# Utilization       Simulated                                             0.496604
#                   Confidence Interval   (0.4921349101610144, 0.5010731113200443)
#                   Analytical                                             0.49995

# %% [markdown]
# ## M/D/1: $\rho$ = 0.1, $\lambda$ = 2, $\mu$ = 20

# %%
sim = queue_sim(lamda = 2, mu = 20, runs = 100, kind='d')

# %%
dist = customers_dist(sim)
display(dist)
plot_pdf(dist, sim.lamda, sim.mu, kind = 'd')
plot_cdf(dist, sim.lamda, sim.mu, kind = 'd')
# Out:
#         pdf       cdf
# N
# 0  0.899645  0.899645
# 1  0.094931  0.994576
# 2  0.005220  0.999796
# 3  0.000198  0.999994
# 4  0.000006  1.000000

# %%
metrics(sim)
# Out:
#                                                                            Metrics
# Wait              Simulated                                               0.052808
#                   Confidence Interval  (0.052711385694194625, 0.05290390543455998)
#                   Analytical                                              0.052765
# Average Customers Simulated                                               0.106194
#                   Confidence Interval   (0.10528535172393218, 0.10710361081678622)
#                   Analytical                                              0.105531
# Utilization       Simulated                                               0.100522
#                   Confidence Interval   (0.09972101383628865, 0.10132316133486419)
#                   Analytical                                              0.099994

# %% [markdown]
# ## M/D/1: $\rho$ = 1.2, $\lambda$ = 12, $\mu$ = 10

# %%
sim = queue_sim(lamda = 12, mu = 10, runs = 100, kind='d')

# %%
dist = customers_dist(sim)
display(dist)
plot_pdf(dist, sim.lamda, sim.mu, kind = 'd', xticks_dist = 10)
plot_cdf(dist, sim.lamda, sim.mu, kind = 'd', xticks_dist = 10)
# Out:
#           pdf       cdf
# N
# 0    0.000397  0.000397
# 1    0.002560  0.002957
# 2    0.002445  0.005402
# 3    0.002577  0.007979
# 4    0.003392  0.011370
# ..        ...       ...
# 375  0.000054  0.999805
# 376  0.000060  0.999864
# 377  0.000105  0.999969
# 378  0.000025  0.999994
# 379  0.000006  1.000000
#
# [380 rows x 2 columns]

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            3.928904
#                   Confidence Interval    (3.768906907081586, 4.088901605252658)
#                   Analytical                                                inf
# Average Customers Simulated                                           47.288777
#                   Confidence Interval   (45.14354066846706, 49.434013786355116)
#                   Analytical                                                inf
# Utilization       Simulated                                            0.996159
#                   Confidence Interval  (0.9951587806804545, 0.9971597250860922)
#                   Analytical                                                1.0

# %% [markdown]
# ## M/D/1: $\rho$ = 2, $\lambda$ = 20, $\mu$ = 10

# %%
sim = queue_sim(lamda = 20, mu = 10, runs = 100, kind='d')

# %%
dist = customers_dist(sim)
display(dist)
plot_pdf(dist, sim.lamda, sim.mu, kind = 'd', xticks_dist = 10)
plot_cdf(dist, sim.lamda, sim.mu, kind = 'd', xticks_dist = 10)
# Out:
#           pdf       cdf
# N
# 0    0.000397  0.000397
# 1    0.002560  0.002957
# 2    0.002445  0.005402
# 3    0.002577  0.007979
# 4    0.003392  0.011370
# ..        ...       ...
# 375  0.000054  0.999805
# 376  0.000060  0.999864
# 377  0.000105  0.999969
# 378  0.000025  0.999994
# 379  0.000006  1.000000
#
# [380 rows x 2 columns]

# %%
metrics(sim)
# Out:
#                                                                        Metrics
# Wait              Simulated                                           8.382833
#                   Confidence Interval   (8.292649644484069, 8.473017286573175)
#                   Analytical                                               inf
# Average Customers Simulated                                         168.936788
#                   Confidence Interval  (166.3398510339078, 171.53372577991638)
#                   Analytical                                               inf
# Utilization       Simulated                                           0.999608
#                   Confidence Interval  (0.999370273177016, 0.9998454450760987)
#                   Analytical                                               1.0
