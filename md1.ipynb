# %%
#autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %load_ext autoreload
# %autoreload 2

# %%
from simulations import queue_sim
from simulated_metrics import customers_dist, metrics
from analytical import dtmc_stationary_distribution
from plot_metrics import plot_mm1_customers_dist, plot_md1_customers_dist
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## M/D/1: $\rho$ = 0.1, $\lambda$ = 1, $\mu$ = 10

# %%
sim = queue_sim(lamda = 1, mu = 10, runs = 100, kind='d')

# %%
sim.service_durations
# Out:
# 1        0.1
# 3        0.1
# 5        0.1
# 7        0.1
# 9        0.1
#         ...
# 99890    0.1
# 99892    0.1
# 99894    0.1
# 99896    0.1
# 99898    0.1
# Name: duration, Length: 49899, dtype: float64

# %%
sim.plot_customers()
# Out:
#         pdf                                            pdf_CI       cdf  \
# N
# 0  0.899058          (0.8981702462884278, 0.8999447849359428)  0.899058
# 1  0.095630        (0.09483579379330909, 0.09642483661069734)  0.994688
# 2  0.005132      (0.004933381985695901, 0.005331212823136305)  0.999820
# 3  0.000206  (0.00017149796033271878, 0.00023991803309865206)  0.999999
# 4  0.000030    (1.063423361748256e-05, 4.975404989423773e-05)  1.000000
#
#                                      cdf_CI
# N
# 0  (0.8981702462884278, 0.8999447849359428)
# 1   (0.9944738692074415, 0.994901792420936)
# 2  (0.9997870879797577, 0.9998531684574519)
# 3  (0.9999976747324868, 1.0000002429129096)
# 4                 (0.9999999999999999, 1.0)

# %%
metrics(sim)
# Out:
#                                                                           Metrics
# Wait              Simulated                                              0.105429
#                   Confidence Interval  (0.10522120587338148, 0.10563721285165552)
#                   Analytical                                             0.105531
# Average Customers Simulated                                              0.106455
#                   Confidence Interval  (0.10542828475594625, 0.10748172944674587)
#                   Analytical                                             0.105531
# Utilization       Simulated                                              0.100942
#                   Confidence Interval   (0.10005521506405715, 0.1018297537115721)
#                   Analytical                                             0.099994

# %% [markdown]
# ## M/D/1: $\rho$ = 0.1, $\lambda$ = 2, $\mu$ = 20

# %%
sim = queue_sim(lamda = 2, mu = 20, runs = 100, kind='d')

# %%
sim.plot_customers()
# Out:
#         pdf                                           pdf_CI       cdf  \
# N
# 0  0.899191         (0.8983219811790333, 0.9000597811002922)  0.899191
# 1  0.095284         (0.0944947011951544, 0.0960742006873877)  0.994475
# 2  0.005313    (0.005138440609922922, 0.0054874769371620405)  0.999788
# 3  0.000222  (0.00019105240902117556, 0.0002529824061207758)  0.999989
# 4  0.000103  (4.938599143353223e-05, 0.00015568450896627105)  0.999995
#
#                                      cdf_CI
# N
# 0  (0.8983219811790333, 0.9000597811002922)
# 1  (0.9942866850845296, 0.9946639790773382)
# 2   (0.999753884249848, 0.9998226974591046)
# 3  (0.9999807475317776, 0.9999979924580379)
# 4    (0.99998540955842, 1.0000046986167799)

# %%
metrics(sim)
# Out:
#                                                                            Metrics
# Wait              Simulated                                               0.052808
#                   Confidence Interval  (0.052711385694194625, 0.05290390543455998)
#                   Analytical                                              0.052765
# Average Customers Simulated                                               0.106194
#                   Confidence Interval   (0.10528535172393218, 0.10710361081678622)
#                   Analytical                                              0.105531
# Utilization       Simulated                                               0.100522
#                   Confidence Interval   (0.09972101383628865, 0.10132316133486419)
#                   Analytical                                              0.099994

# %% [markdown]
# ## M/D/1: $\rho$ = 1.2, $\lambda$ = 12, $\mu$ = 10

# %%
sim = queue_sim(lamda = 12, mu = 10, runs = 100, kind='d')

# %%
sim.plot_customers()
# Out:
#           pdf       cdf
# N
# 0    0.000397  0.000397
# 1    0.002560  0.002957
# 2    0.002445  0.005402
# 3    0.002577  0.007979
# 4    0.003392  0.011370
# ..        ...       ...
# 375  0.000054  0.999805
# 376  0.000060  0.999864
# 377  0.000105  0.999969
# 378  0.000025  0.999994
# 379  0.000006  1.000000
#
# [380 rows x 2 columns]

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            3.928904
#                   Confidence Interval    (3.768906907081586, 4.088901605252658)
#                   Analytical                                                inf
# Average Customers Simulated                                           47.288777
#                   Confidence Interval   (45.14354066846706, 49.434013786355116)
#                   Analytical                                                inf
# Utilization       Simulated                                            0.996159
#                   Confidence Interval  (0.9951587806804545, 0.9971597250860922)
#                   Analytical                                                1.0

# %% [markdown]
# ## M/D/1: $\rho$ = 2, $\lambda$ = 20, $\mu$ = 10

# %%
sim = queue_sim(lamda = 20, mu = 10, runs = 100, kind='d')

# %%
sim.plot_customers()
# Out:
#           pdf       cdf
# N
# 0    0.000397  0.000397
# 1    0.002560  0.002957
# 2    0.002445  0.005402
# 3    0.002577  0.007979
# 4    0.003392  0.011370
# ..        ...       ...
# 375  0.000054  0.999805
# 376  0.000060  0.999864
# 377  0.000105  0.999969
# 378  0.000025  0.999994
# 379  0.000006  1.000000
#
# [380 rows x 2 columns]

# %%
metrics(sim)
# Out:
#                                                                        Metrics
# Wait              Simulated                                           8.382833
#                   Confidence Interval   (8.292649644484069, 8.473017286573175)
#                   Analytical                                               inf
# Average Customers Simulated                                         168.936788
#                   Confidence Interval  (166.3398510339078, 171.53372577991638)
#                   Analytical                                               inf
# Utilization       Simulated                                           0.999608
#                   Confidence Interval  (0.999370273177016, 0.9998454450760987)
#                   Analytical                                               1.0
