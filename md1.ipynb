# %%
#autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from simulations import queue_sim
from simulated_metrics import customers_dist, metrics
from analytical import dtmc_stationary_distribution
from plot_metrics import plot_mm1_customers_dist, plot_md1_customers_dist
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## M/D/1: $\rho$ = 0.1, $\lambda$ = 1, $\mu$ = 10

# %%
sim = queue_sim(lamda = 1, mu = 10, runs = 3000, max_events = 1e100, kind='d', export = True)

# %%
sim.service_durations
# Out:
# 1          0.1
# 5          0.1
# 6          0.1
# 7          0.1
# 9          0.1
#           ...
# 6012248    0.1
# 6012250    0.1
# 6012252    0.1
# 6012254    0.1
# 6012256    0.1
# Name: duration, Length: 3005967, dtype: float64

# %%
sim.plot_customers(figsize = (10,8))
# Out:
#         pdf                                            pdf_CI       cdf  \
# N
# 0  0.899880          (0.8997661597801296, 0.8999947697012611)  0.899880
# 1  0.094773        (0.09466905228192611, 0.09487677408785529)  0.994653
# 2  0.005146      (0.005121761861009472, 0.005169827541687441)  0.999799
# 3  0.000197  (0.00019279251874108072, 0.00020123519385614776)  0.999994
# 4  0.000035     (3.21096844078966e-05, 3.822923530262951e-05)  1.000000
# 5  0.000024   (1.4803259142329484e-05, 3.246171365184391e-05)  1.000000
#
#                                      cdf_CI
# N
# 0  (0.8997661597801296, 0.8999947697012611)
# 1   (0.994627415256537, 0.9946793405946351)
# 2  (0.9997946356817153, 0.9998037095721535)
# 3  (0.9999935784179017, 0.9999949856140093)
# 4  (0.9999997975661019, 0.9999999503540433)
# 5                                (1.0, 1.0)
# Queue Size PMF M/D/1 λ = 1, μ = 10, ρ = 0.1
# Queue Size CMF M/D/1 λ = 1, μ = 10, ρ = 0.1

# %%
sim.plot_wait(figsize = (10,8))
# Out:
#                                                  cdf  \
# cut
# (0.09999999999999307, 0.11729055031494076)  0.872351
# (0.11729055031494076, 0.13458110062988846)  0.891399
# (0.13458110062988846, 0.15187165094483618)  0.913551
# (0.15187165094483618, 0.16916220125978387)  0.938534
# (0.16916220125978387, 0.18645275157473157)  0.966823
# (0.18645275157473157, 0.20374330188967926)  0.992199
# (0.20374330188967926, 0.22103385220462696)  0.995190
# (0.22103385220462696, 0.23832440251957465)  0.997693
# (0.23832440251957465, 0.25561495283452235)  1.000000
#
#                                                                               cdf_CI
# cut
# (0.09999999999999307, 0.11729055031494076)  (0.8718599644080435, 0.8728429098469915)
# (0.11729055031494076, 0.13458110062988846)  (0.8909270558069142, 0.8918713745761526)
# (0.13458110062988846, 0.15187165094483618)  (0.9131095021644265, 0.9139921734762771)
# ...

# %%
metrics(sim)
# Out:
#                                                                           Metrics
# Wait              Simulated                                              0.105539
#                   Confidence Interval  (0.10551308241282098, 0.10556543792883938)
#                   Analytical                                             0.105555
# Average Customers Simulated                                              0.105861
#                   Confidence Interval  (0.10573013458980875, 0.10599098866046468)
#                   Analytical                                             0.105555
# Utilization       Simulated                                               0.10012
#                   Confidence Interval  (0.10000523029873884, 0.10023384021987045)
#                   Analytical                                                  0.1

# %% [markdown]
# ## M/D/1: $\rho$ = 0.1, $\lambda$ = 2, $\mu$ = 20

# %%
sim = queue_sim(lamda = 2, mu = 20, runs = 3000, max_events=1e100, kind='d')

# %%
sim.plot_customers(figsize = (10,8))
# Out:
#         pdf                                            pdf_CI       cdf  \
# N
# 0  0.900007          (0.8999281416839099, 0.9000848645074876)  0.900007
# 1  0.094645         (0.0945735246346669, 0.09471551271741208)  0.994651
# 2  0.005144      (0.005127459666285776, 0.005161388530981597)  0.999795
# 3  0.000198  (0.00019529922961152016, 0.00020136248448154298)  0.999994
# 4  0.000020    (1.907567215351028e-05, 2.173960351435145e-05)  1.000000
# 5  0.000015   (9.828587833283934e-06, 2.0196088462947424e-05)  1.000000
#
#                                      cdf_CI
# N
# 0  (0.8999281416839099, 0.9000848645074876)
# 1   (0.994632735822384, 0.9946693077210925)
# 2   (0.999792181402828, 0.9997987103379159)
# 3  (0.9999932208505942, 0.9999943326042429)
# 4  (0.9999997217666371, 0.9999999130097975)
# 5   (0.9999999632077463, 1.000000011848353)
# Queue Size PMF M/D/1 λ = 2, μ = 20, ρ = 0.1
# Queue Size CMF M/D/1 λ = 2, μ = 20, ρ = 0.1

# %%
sim.plot_wait(figsize = (10,8))
# Out:
#                                                  cdf  \
# cut
# (0.049999999999954525, 0.0596157637407387)  0.872527
# (0.0596157637407387, 0.06923152748152288)   0.894345
# (0.06923152748152288, 0.07884729122230706)  0.919880
# (0.07884729122230706, 0.08846305496309123)  0.949135
# (0.08846305496309123, 0.09807881870387541)  0.982576
# (0.09807881870387541, 0.1076945824446596)   0.992462
# (0.1076945824446596, 0.11731034618544377)   0.995480
# (0.11731034618544377, 0.12692610992622794)  0.998036
# (0.12692610992622794, 0.13654187366701215)  1.000000
#
#                                                                               cdf_CI
# cut
# (0.049999999999954525, 0.0596157637407387)  (0.8721721196498078, 0.8728828004266727)
# (0.0596157637407387, 0.06923152748152288)   (0.8940058293272282, 0.8946849559764576)
# (0.06923152748152288, 0.07884729122230706)  (0.9195680615919343, 0.9201909642909899)
# ...

# %%
metrics(sim)
# Out:
#                                                                           Metrics
# Wait              Simulated                                              0.052778
#                   Confidence Interval  (0.052769146781670745, 0.0527876118396943)
#                   Analytical                                             0.052778
# Average Customers Simulated                                              0.105649
#                   Confidence Interval  (0.10555879455847068, 0.10573869344613969)
#                   Analytical                                             0.105556
# Utilization       Simulated                                              0.099993
#                   Confidence Interval  (0.09991513549251242, 0.10007185831609013)
#                   Analytical                                                  0.1

# %% [markdown]
# ## M/D/1: $\rho$ = 1.2, $\lambda$ = 12, $\mu$ = 10

# %%
sim = queue_sim(lamda = 12, mu = 10, runs = 3000, max_events = 1e100, kind='d')

# %%
sim.plot_customers(figsize = (10,8), max_ticks = 10)
# Out:
#            pdf                                             pdf_CI       cdf  \
# N
# 0     0.000266     (0.0002539103363947372, 0.0002774023890090716)  0.000266
# 1     0.000421   (0.00040487839475699403, 0.00043615581803265835)  0.000602
# 2     0.000475    (0.00045714510292266236, 0.0004919273400282944)  0.001077
# 3     0.000501    (0.00048281434730491695, 0.0005186970713011175)  0.001577
# 4     0.000506     (0.0004881186154786183, 0.0005233889541507117)  0.002083
# ...        ...                                                ...       ...
# 2363  0.000502   (-0.00021404916350986495, 0.0012181309742945435)  0.999990
# 2364  0.000327     (3.618292860029421e-05, 0.0006171205665938492)  0.999990
# 2365  0.000286     (7.423476458656226e-05, 0.0004969998179795395)  0.999990
# 2366  0.000339    (-5.731233069157759e-05, 0.0007360920931956459)  0.999990
# 2367  0.000102  (-5.7482382391735114e-05, 0.00026234324766321454)  0.999990
#
#                                               cdf_CI
# ...

# %%
sim.plot_wait(figsize = (10,8))
# Out:
#                                                 cdf  \
# cut
# (0.09999999999999995, 16.807228334139097)  0.012640
# (16.807228334139097, 33.51445666827819)    0.049833
# (33.51445666827819, 50.22168500241729)     0.111725
# (50.22168500241729, 66.92891333655638)     0.198951
# (66.92891333655638, 83.63614167069548)     0.310155
# (83.63614167069548, 100.34337000483457)    0.446700
# (100.34337000483457, 117.05059833897366)   0.607049
# (117.05059833897366, 133.75782667311276)   0.791995
# (133.75782667311276, 150.46505500725186)   1.000000
#
#                                                                                  cdf_CI
# cut
# (0.09999999999999995, 16.807228334139097)  (0.012555246901406362, 0.012723924455094529)
# (16.807228334139097, 33.51445666827819)     (0.049590722463014714, 0.05007467551300428)
# (33.51445666827819, 50.22168500241729)       (0.11128312850222051, 0.11216651402673249)
# ...

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                           83.541851
#                   Confidence Interval     (83.3680762180993, 83.71562658763668)
#                   Analytical                                                inf
# Average Customers Simulated                                         1003.103246
#                   Confidence Interval  (1000.8160243937019, 1005.3904683471757)
#                   Analytical                                                inf
# Utilization       Simulated                                            0.999818
#                   Confidence Interval  (0.9998092237989987, 0.9998275354010667)
#                   Analytical                                                1.0

# %% [markdown]
# ## M/D/1: $\rho$ = 2, $\lambda$ = 20, $\mu$ = 10

# %%
sim = queue_sim(lamda = 20, mu = 10, runs = 3000, max_events = 1e100, kind='d')

# %%
sim.plot_customers(figsize = (10,8), max_ticks = 10)
# Out:
#             pdf                                            pdf_CI       cdf  \
# N
# 0      0.000061    (5.653597348314864e-05, 6.580650587202384e-05)  0.000061
# 1      0.000081    (7.794353530359897e-05, 8.408320749114272e-05)  0.000094
# 2      0.000093    (8.965810514648573e-05, 9.660421024200989e-05)  0.000187
# 3      0.000099   (9.558383457278527e-05, 0.00010245041194627035)  0.000286
# 4      0.000099   (9.551588685040824e-05, 0.00010238400016073417)  0.000385
# ...         ...                                               ...       ...
# 10457  0.000067   (3.4277602445820576e-05, 9.939769895551206e-05)  0.999998
# 10458  0.000194    (3.740149968816677e-06, 0.0003836466099705534)  0.999998
# 10459  0.000297   (-0.00015559919473839243, 0.000750047471543863)  0.999998
# 10460  0.000220  (-0.00016704905082686044, 0.0006062795256782468)  0.999998
# 10461  0.000108   (9.170383238368594e-05, 0.00012391174895194887)  0.999998
#
# ...

# %%
sim.plot_wait(figsize = (10,8))
# Out:
#                                                cdf  \
# cut
# (0.09999999999999998, 50.096502451368)    0.012388
# (50.096502451368, 100.093004902736)       0.049449
# (100.093004902736, 150.089507354104)      0.111146
# (150.089507354104, 200.086009805472)      0.197533
# (200.086009805472, 250.08251225684)       0.308677
# (250.08251225684, 300.07901470820804)     0.444456
# (300.07901470820804, 350.07551715957607)  0.604933
# (350.07551715957607, 400.07201961094404)  0.790114
# (400.07201961094404, 450.068522062312)    1.000000
#
#                                                                                 cdf_CI
# cut
# (0.09999999999999998, 50.096502451368)    (0.012371280481144829, 0.012404354635299169)
# (50.096502451368, 100.093004902736)        (0.049400785446356114, 0.04949666491037811)
# (100.093004902736, 150.089507354104)        (0.11105944381530534, 0.11123223124522734)
# (150.089507354104, 200.086009805472)        (0.19740148759521597, 0.19766363421194916)
# ...

# %%
metrics(sim)
# Out:
#                                                                        Metrics
# Wait              Simulated                                         250.103188
#                   Confidence Interval  (250.00013498877007, 250.2062414275419)
#                   Analytical                                               inf
# Average Customers Simulated                                        5002.836465
#                   Confidence Interval   (4999.908843020467, 5005.764086041122)
#                   Analytical                                               inf
# Utilization       Simulated                                           0.999987
#                   Confidence Interval    (0.99998594684525, 0.999988565138218)
#                   Analytical                                               1.0
