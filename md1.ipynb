# %%
#autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from simulations import queue_sim
from simulated_metrics import customers_dist, metrics
from analytical import dtmc_stationary_distribution
from plot_metrics import plot_mm1_customers_dist, plot_md1_customers_dist
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## M/D/1: $\rho$ = 0.1, $\lambda$ = 1, $\mu$ = 10

# %%
sim = queue_sim(lamda = 1, mu = 10, runs = 100, kind='d')

# %%
sim.service_durations
# Out:
# 1        0.1
# 3        0.1
# 5        0.1
# 8        0.1
# 9        0.1
#         ...
# 99890    0.1
# 99892    0.1
# 99894    0.1
# 99896    0.1
# 99898    0.1
# Name: duration, Length: 49900, dtype: float64

# %%
sim.plot_customers()
# Out:
#         pdf                                           pdf_CI       cdf  \
# N
# 0  0.900058          (0.899033770274614, 0.9010813350920556)  0.900058
# 1  0.094662        (0.0937193370524142, 0.09560393679956664)  0.994719
# 2  0.005090     (0.004901207906871988, 0.005277896872246697)  0.999809
# 3  0.000203  (0.00016973717645632627, 0.0002357849175074143)  0.999997
# 4  0.000027    (9.63562633385985e-06, 4.416892211581535e-05)  1.000000
#
#                                      cdf_CI
# N
# 0   (0.899033770274614, 0.9010813350920556)
# 1  (0.9945136660224319, 0.9949247131962178)
# 2  (0.9997748922372983, 0.9998425917604704)
# 3  (0.9999950267594991, 0.9999995927856556)
# 4                                (1.0, 1.0)

# %%
metrics(sim)
# Out:
#                                                                           Metrics
# Wait              Simulated                                              0.105465
#                   Confidence Interval  (0.10525919347290681, 0.10567137205260498)
#                   Analytical                                             0.105531
# Average Customers Simulated                                              0.105437
#                   Confidence Interval  (0.10429444637272138, 0.10657990495207094)
#                   Analytical                                             0.105531
# Utilization       Simulated                                              0.099942
#                   Confidence Interval  (0.09891866490794453, 0.10096622972538617)
#                   Analytical                                             0.099994

# %% [markdown]
# ## M/D/1: $\rho$ = 0.1, $\lambda$ = 2, $\mu$ = 20

# %%
sim = queue_sim(lamda = 2, mu = 20, runs = 100, kind='d')

# %%
sim.plot_customers()
# Out:
#         pdf                                            pdf_CI       cdf  \
# N
# 0  0.899553           (0.8986973854200265, 0.900409524235333)  0.899553
# 1  0.095093        (0.09428713540460826, 0.09589789801882315)  0.994646
# 2  0.005162      (0.004993642397591978, 0.005330684186852428)  0.999808
# 3  0.000213  (0.00018266890503086726, 0.00024336889388838656)  0.999998
# 4  0.000038   (1.3625013546208815e-05, 6.231991522463493e-05)  1.000000
#
#                                      cdf_CI
# N
# 0   (0.8986973854200265, 0.900409524235333)
# 1  (0.9944668734542036, 0.9948250696245874)
# 2  (0.9997772269229154, 0.9998390427403202)
# 3  (0.9999955035617958, 0.9999999397424779)
# 4                                (1.0, 1.0)

# %%
metrics(sim)
# Out:
#                                                                            Metrics
# Wait              Simulated                                               0.052759
#                   Confidence Interval  (0.052667466830543005, 0.05285033018075709)
#                   Analytical                                              0.052765
# Average Customers Simulated                                               0.106014
#                   Confidence Interval   (0.10507124619556293, 0.10695733578918257)
#                   Analytical                                              0.105531
# Utilization       Simulated                                               0.100447
#                   Confidence Interval   (0.09959047576466688, 0.10130261457997335)
#                   Analytical                                              0.099994

# %% [markdown]
# ## M/D/1: $\rho$ = 1.2, $\lambda$ = 12, $\mu$ = 10

# %%
sim = queue_sim(lamda = 12, mu = 10, runs = 1000, kind='d')

# %%
sim.plot_customers(total_ticks = 2)
# Out:
#           pdf                                           pdf_CI       cdf  \
# N
# 0    0.001796    (0.001056292176388111, 0.0025366825443310205)  0.001796
# 1    0.002752    (0.0021842154816362003, 0.003319671227033182)  0.003273
# 2    0.002755    (0.002262423242694383, 0.0032478599513739593)  0.006028
# 3    0.002700    (0.0021329129644307226, 0.003266379055778622)  0.008728
# 4    0.003099    (0.002381839970660768, 0.0038155094228492278)  0.011826
# ..        ...                                              ...       ...
# 367  0.002658    (0.0014552518094859328, 0.003859784949612692)  0.999834
# 368  0.004197    (0.0029689000573276366, 0.005424575209017035)  0.999917
# 369  0.000930   (0.0007789746585417687, 0.0010807862560246852)  0.999936
# 370  0.001970   (-0.0002732697107706481, 0.004213285264861559)  0.999975
# 371  0.001228  (-0.0009645571754457634, 0.0034212755755168005)  1.000000
#
#                                             cdf_CI
# N
# 0    (0.001056292176388111, 0.0025366825443310205)
# 1    (0.0025364919513868834, 0.004009357426291047)
# 2     (0.005018451259650581, 0.007037681312095695)
# 3     (0.007446754566793968, 0.010008670025161653)
# 4      (0.010150626681011944, 0.01350214730445367)
# ..                                             ...
# 367       (0.9995920160104688, 1.0000749845868298)
# 368        (0.9997888283409605, 1.000046041761665)
# 369       (0.9998279738217261, 1.0000440914991906)
# 370       (0.9999295264617285, 1.0000213391702701)
# 371                                     (1.0, 1.0)
#
# [372 rows x 4 columns]

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            3.980442
#                   Confidence Interval    (3.925593680642703, 4.035289548377602)
#                   Analytical                                                inf
# Average Customers Simulated                                           48.050617
#                   Confidence Interval   (47.311513236365535, 48.78972146961582)
#                   Analytical                                                inf
# Utilization       Simulated                                            0.995952
#                   Confidence Interval  (0.9956250555133497, 0.9962792165372258)
#                   Analytical                                                1.0

# %% [markdown]
# ## M/D/1: $\rho$ = 2, $\lambda$ = 20, $\mu$ = 10

# %%
sim = queue_sim(lamda = 20, mu = 10, runs = 100, kind='d')

# %%
sim.plot_customers(total_ticks = 5)
# Out:
#           pdf                                           pdf_CI       cdf  \
# N
# 0    0.001796    (0.001056292176388111, 0.0025366825443310205)  0.001796
# 1    0.002752    (0.0021842154816362003, 0.003319671227033182)  0.003273
# 2    0.002755    (0.002262423242694383, 0.0032478599513739593)  0.006028
# 3    0.002700    (0.0021329129644307226, 0.003266379055778622)  0.008728
# 4    0.003099    (0.002381839970660768, 0.0038155094228492278)  0.011826
# ..        ...                                              ...       ...
# 367  0.002658    (0.0014552518094859328, 0.003859784949612692)  0.999834
# 368  0.004197    (0.0029689000573276366, 0.005424575209017035)  0.999917
# 369  0.000930   (0.0007789746585417687, 0.0010807862560246852)  0.999936
# 370  0.001970   (-0.0002732697107706481, 0.004213285264861559)  0.999975
# 371  0.001228  (-0.0009645571754457634, 0.0034212755755168005)  1.000000
#
#                                             cdf_CI
# N
# 0    (0.001056292176388111, 0.0025366825443310205)
# 1    (0.0025364919513868834, 0.004009357426291047)
# 2     (0.005018451259650581, 0.007037681312095695)
# 3     (0.007446754566793968, 0.010008670025161653)
# 4      (0.010150626681011944, 0.01350214730445367)
# ..                                             ...
# 367       (0.9995920160104688, 1.0000749845868298)
# 368        (0.9997888283409605, 1.000046041761665)
# 369       (0.9998279738217261, 1.0000440914991906)
# 370       (0.9999295264617285, 1.0000213391702701)
# 371                                     (1.0, 1.0)
#
# [372 rows x 4 columns]

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            8.333729
#                   Confidence Interval    (8.246078325880822, 8.421380435521266)
#                   Analytical                                                inf
# Average Customers Simulated                                           166.18387
#                   Confidence Interval   (164.0433202906749, 168.32442058511543)
#                   Analytical                                                inf
# Utilization       Simulated                                            0.999479
#                   Confidence Interval  (0.9992135730596028, 0.9997444642713884)
#                   Analytical                                                1.0
