# %%
#autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from simulations import queue_sim
from simulated_metrics import customers_dist, metrics, wait_dist
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## M/M/1: $\rho$ = 0.1, $\lambda$ = 1, $\mu$ = 10

# %%
sim = queue_sim(lamda = 1, mu = 10, runs = 100)

# %%
sim.data
# Out:
#       type        time  N  run   holding
# 0        a    0.000000  1    0  0.017447
# 1        s    0.017447  0    0  0.760931
# 2        a    0.778378  1    0  0.297190
# 3        s    1.075568  0    0  1.977685
# 4        a    3.053253  1    0  0.039578
# ...    ...         ... ..  ...       ...
# 99895    a  493.425400  1   99  0.182387
# 99896    s  493.607787  0   99  1.883275
# 99897    a  495.491062  1   99  0.094016
# 99898    s  495.585078  0   99  0.472569
# 99899    a  496.057646  1   99  0.081056
#
# [99900 rows x 5 columns]

# %%
sim.service_durations
# Out:
# 1        0.017447
# 3        0.297190
# 5        0.039578
# 7        0.039056
# 9        0.089178
#            ...
# 99890    0.145202
# 99892    0.018022
# 99894    0.091115
# 99896    0.182387
# 99898    0.094016
# Name: duration, Length: 49899, dtype: float64

# %%
sim.plot_customers()
# Out:
#         pdf                                           pdf_CI       cdf  \
# N
# 0  0.899442         (0.8983022990829672, 0.9005822856826626)  0.899442
# 1  0.090560       (0.08960748439033835, 0.09151281130458681)  0.990002
# 2  0.008967      (0.008603512761549357, 0.00932960667655893)  0.998969
# 3  0.000944    (0.0008336354780865237, 0.001053557256535091)  0.999903
# 4  0.000264  (0.00017161103923288816, 0.0003559812056424144)  0.999990
# 5  0.000461   (0.0002020953341859631, 0.0007196632319463821)  0.999999
#
#                                      cdf_CI
# N
# 0  (0.8983022990829672, 0.9005822856826626)
# 1  (0.9895964807920902, 0.9904083996684644)
# 2  (0.9988439700807471, 0.9990940298179162)
# 3  (0.9998618046876503, 0.9999445160182886)
# 4  (0.9999760629672255, 1.0000043631795221)
# 5  (0.9999983204441537, 1.0000005408739165)

# %%
metrics(sim)
# Out:
#                                                                           Metrics
# Wait              Simulated                                              0.111679
#                   Confidence Interval   (0.1105205706659365, 0.11283644203905459)
#                   Analytical                                             0.111105
# Average Customers Simulated                                              0.111714
#                   Confidence Interval  (0.11023377927884331, 0.11319479094729978)
#                   Analytical                                             0.111105
# Utilization       Simulated                                              0.100558
#                   Confidence Interval  (0.09941771431733726, 0.10169770091703279)
#                   Analytical                                             0.099999

# %% [markdown]
# ## M/M/1: $\rho$ = 0.2, $\lambda$ = 1, $\mu$ = 2

# %%
sim = queue_sim(lamda = 1, mu = 2)

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            1.044529
#                   Confidence Interval   (0.9596774025580712, 1.129381557553095)
#                   Analytical                                           0.999542
# Average Customers Simulated                                            1.069699
#                   Confidence Interval  (0.9580920778691076, 1.1813049857858402)
#                   Analytical                                           0.999542
# Utilization       Simulated                                            0.514658
#                   Confidence Interval  (0.4882410563438816, 0.5410757409668286)
#                   Analytical                                           0.499985

# %%
sim.plot_customers()
# Out:
#          pdf                                          pdf_CI       cdf  \
# N
# 0   0.485342       (0.45892425903317124, 0.5117589436561183)  0.485342
# 1   0.251061       (0.23497899312745446, 0.2671423665390044)  0.736402
# 2   0.130996      (0.12045300594089953, 0.14153824411306581)  0.867398
# 3   0.062288       (0.05250821223318786, 0.0720672111998785)  0.929686
# 4   0.030782     (0.024621940921258818, 0.03694222788050944)  0.960468
# 5   0.017660      (0.013254063683213382, 0.0220662341013188)  0.978128
# 6   0.012061    (0.009824850437693045, 0.014296933016230515)  0.988983
# 7   0.005396    (0.003384456177329978, 0.007407596783056809)  0.993839
# 8   0.002704   (0.0011922438234899658, 0.004216094756752421)  0.996002
# 9   0.002459    (0.0009258314586882406, 0.00399273572633002)  0.997724
# 10  0.002467    (0.001021668417299486, 0.003911958345893175)  0.998711
# 11  0.001226  (0.0001684582806039368, 0.0022844050724727446)  0.999079
#
#                                        cdf_CI
# N
# 0   (0.45892425903317124, 0.5117589436561183)
# 1     (0.7077777605536564, 0.765026801802092)
# 2    (0.8430374217319991, 0.8917583906777149)
# 3    (0.9132546105485203, 0.9461166252942602)
# 4    (0.9495856115418513, 0.9713497931026971)
# 5     (0.9712205996478244, 0.985035102781256)
# 6    (0.9843968329782576, 0.9935684745593544)
# 7    (0.9898138862690169, 0.9978642689329431)
# 8    (0.9924770863270481, 0.9995277397391057)
# 9     (0.994813891347635, 1.0006339317480317)
# 10   (0.9965094122587443, 1.0009118615421995)
# 11   (0.9972817708901284, 1.0008753619167383)

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            1.044529
#                   Confidence Interval   (0.9596774025580712, 1.129381557553095)
#                   Analytical                                           0.999542
# Average Customers Simulated                                            1.069699
#                   Confidence Interval  (0.9580920778691076, 1.1813049857858402)
#                   Analytical                                           0.999542
# Utilization       Simulated                                            0.514658
#                   Confidence Interval  (0.4882410563438816, 0.5410757409668286)
#                   Analytical                                           0.499985

# %% [markdown]
# ## M/M/1: $\rho$ = 1.2, $\lambda$ = 12, $\mu$ = 10

# %%
sim = queue_sim(lamda = 12, mu = 10, runs = 100)

# %%
sim.data
# Out:
#       type       time    N  run   holding
# 0        a   0.000000    1    0  0.055790
# 1        a   0.055790    2    0  0.028273
# 2        a   0.084062    3    0  0.006988
# 3        s   0.091050    2    0  0.029452
# 4        a   0.120503    3    0  0.016451
# ...    ...        ...  ...  ...       ...
# 99895    a  46.985673  111   99  0.004843
# 99896    s  46.990515  110   99  0.052027
# 99897    a  47.042542  111   99  0.007865
# 99898    s  47.050407  110   99  0.026578
# 99899    s  47.076985  109   99  0.121470
#
# [99900 rows x 5 columns]

# %%
sim.plot_customers(xticks_dist = 10)
# Out:
#           pdf                                          pdf_CI       cdf  \
# N
# 0    0.010310    (0.008430291576852498, 0.012188877077716266)  0.010310
# 1    0.010876      (0.00889785079320099, 0.01285418649779059)  0.019639
# 2    0.010307     (0.008397945284773979, 0.01221570372560182)  0.029946
# 3    0.009959    (0.007973205028092324, 0.011945753801549618)  0.039905
# 4    0.009620    (0.007663349875188133, 0.011576561484572506)  0.049525
# ..        ...                                             ...       ...
# 161  0.004634  (-0.0001451785250814186, 0.009413488122559162)  0.998550
# 162  0.004255  (-0.0021047279070677593, 0.010614206918824306)  0.998635
# 163  0.006645   (-0.005972692891656896, 0.019263052955517362)  0.998768
# 164  0.007446   (-0.006049087736790051, 0.020942041425777966)  0.998917
# 165  0.003179   (0.0007949683147614583, 0.005562560983022581)  0.998981
#
#                                            cdf_CI
# N
# 0    (0.008430291576852498, 0.012188877077716266)
# 1    (0.016110532384377676, 0.023167798262997353)
# 2      (0.02488079326230601, 0.03501118639544481)
# 3      (0.03324851966979722, 0.04656241881759554)
# 4     (0.041449360897541934, 0.05760148894961148)
# ..                                            ...
# 161      (0.9957942767528187, 1.0013062678500273)
# 162      (0.9960261428434455, 1.0012445913396353)
# 163       (0.9964147883640553, 1.001121753020303)
# 164      (0.9968439230041095, 1.0009904774540284)
# 165       (0.996993287790038, 1.0009682632540555)
#
# [166 rows x 4 columns]

# %%
metrics(sim)
# Out:
#                                                                        Metrics
# Wait              Simulated                                           4.058976
#                   Confidence Interval  (3.1619414285133898, 4.956010364312228)
#                   Analytical                                               inf
# Average Customers Simulated                                           49.25997
#                   Confidence Interval   (37.53685426988881, 60.98308494572978)
#                   Analytical                                               inf
# Utilization       Simulated                                           0.992339
#                   Confidence Interval  (0.987587160987847, 0.9970899650916527)
#                   Analytical                                               1.0

# %% [markdown]
# Os resultados não batem porque essa fila não entra em estado estacionário. Se aumentarmos a iterações máximas de eventos e tempo de simulação, iremos obter tamanhos máximos de fila cada vez maiores

# %% [markdown]
# ## M/M/1: $\rho$ = 2, $\lambda$ = 20, $\mu$ = 10

# %%
sim = queue_sim(lamda = 20, mu = 10, runs = 100)

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            8.438015
#                   Confidence Interval     (8.26181126008088, 8.614219212055652)
#                   Analytical                                                inf
# Average Customers Simulated                                          169.867377
#                   Confidence Interval  (166.68966898096184, 173.04508488681844)
#                   Analytical                                                inf
# Utilization       Simulated                                            0.998559
#                   Confidence Interval  (0.9980072251599287, 0.9991104516257993)
#                   Analytical                                                1.0

# %%
sim.plot_customers(figsize=(20,5), xticks_dist = 10)
# Out:
#           pdf                                           pdf_CI       cdf  \
# N
# 0    0.002719     (0.001803261340053508, 0.003635084347252376)  0.002719
# 1    0.002670   (0.0020953806298656327, 0.0032445724266180155)  0.004111
# 2    0.003021    (0.0023496917663046657, 0.003691868247033131)  0.007132
# 3    0.002542   (0.0020807977996582247, 0.0030038509720358274)  0.009674
# 4    0.002626    (0.002160468229293904, 0.0030912983497798714)  0.012300
# ..        ...                                              ...       ...
# 381  0.002602    (0.0012236323864652976, 0.003980280351872123)  0.999849
# 382  0.002212  (-0.0008421608951587035, 0.0052660576261444846)  0.999893
# 383  0.002448  (-0.00043980023787972477, 0.005335439781568729)  0.999942
# 384  0.002349   (-0.0021733605994402505, 0.006872214368691678)  0.999989
# 385  0.000529  (-0.0001236721371185367, 0.0011816922757436408)  1.000000
#
#                                             cdf_CI
# N
# 0     (0.001803261340053508, 0.003635084347252376)
# 1    (0.0031417230481434358, 0.005080553222612329)
# 2     (0.005669473740230338, 0.008594362543863225)
# 3     (0.007970983828654582, 0.011377501227133038)
# 4     (0.010404895788951433, 0.014195355845909963)
# ..                                             ...
# 381       (0.9996304958526455, 1.0000679759437034)
# 382       (0.9997077580638805, 1.0000791916670884)
# 383       (0.9998345025407749, 1.0000503599810675)
# 384        (0.999972193748007, 1.0000066458492203)
# 385                                     (1.0, 1.0)
#
# [386 rows x 4 columns]

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            8.931407
#                   Confidence Interval    (8.532330517085615, 9.330483848209425)
#                   Analytical                                                inf
# Average Customers Simulated                                          175.918048
#                   Confidence Interval  (167.26268573520247, 184.57341074514022)
#                   Analytical                                                inf
# Utilization       Simulated                                            0.998785
#                   Confidence Interval   (0.9974997457681739, 1.000069781249869)
#                   Analytical                                                1.0
