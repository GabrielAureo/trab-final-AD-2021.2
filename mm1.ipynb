# %%
#autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %load_ext autoreload
# %autoreload 2

# %%
from simulations import queue_sim
from simulated_metrics import customers_dist, metrics, wait_dist
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## M/M/1: $\rho$ = 0.1, $\lambda$ = 1, $\mu$ = 10

# %%
sim = queue_sim(lamda = 1, mu = 10, runs = 3000, max_events = 1e100)

# %%
sim.data
# Out:
#         type        time  N   run   holding
# 0          a    0.000000  1     0  0.016028
# 1          s    0.016028  0     0  0.495080
# 2          a    0.511109  1     0  0.141712
# 3          s    0.652820  0     0  0.145774
# 4          a    0.798595  1     0  0.088358
# ...      ...         ... ..   ...       ...
# 5998685    s  997.035410  0  2999  2.003529
# 5998686    a  999.038939  1  2999  0.038415
# 5998687    s  999.077354  0  2999  0.130181
# 5998688    a  999.207535  1  2999  0.040815
# 5998689    s  999.248350  0  2999  1.020205
#
# [5998690 rows x 5 columns]

# %%
sim.plot_customers(figsize=(10,8))
# Out:
#         pdf                                           pdf_CI       cdf  \
# N
# 0  0.900171         (0.9000141486633388, 0.9003275438166403)  0.900171
# 1  0.089902       (0.08976778678103274, 0.09003615578838396)  0.990073
# 2  0.008944       (0.008894520206483002, 0.0089935691000729)  0.999017
# 3  0.000889   (0.0008730827338693472, 0.0009048333347938471)  0.999906
# 4  0.000156  (0.00014923414036324323, 0.0001635030431709837)  0.999991
# 5  0.000112   (9.715245267572832e-05, 0.0001260478939341634)  0.999999
# 6  0.000094  (4.325941301498955e-05, 0.00014563721176521395)  1.000000
# 7  0.000115  (-9.558328001924291e-05, 0.0003252459577531877)  1.000000
#
#                                      cdf_CI
# N
# 0  (0.9000141486633388, 0.9003275438166403)
# 1   (0.9900151047875768, 0.990130530261819)
# 2  (0.9989986108763265, 0.9990351134796251)
# 3  (0.9999002700752717, 0.9999113703493434)
# 4    (0.999989319603249, 0.999992762586392)
# 5  (0.9999987366729386, 0.9999997879422362)
# 6  (0.9999997785987131, 1.0000000682928347)
# 7                                (1.0, 1.0)
# array([9.00000009e-01, 9.00000009e-02, 9.00000009e-03, 9.00000009e-04,
#        9.00000009e-05, 9.00000009e-06, 9.00000009e-07, 9.00000009e-08])
# array([0.90000001, 0.99000001, 0.99900001, 0.99990001, 0.99999001,
#        0.99999901, 0.99999991, 1.        ])

# %%
sim.plot_wait(figsize = (10,8))
# Out:
#                                                     cdf  \
# cut
# (0.00011287342311655124, 0.08085641808707149)  0.168080
# (0.08085641808707149, 0.16159996275102642)     0.433399
# (0.16159996275102642, 0.24234350741498134)     0.649643
# (0.24234350741498134, 0.3230870520789363)      0.796317
# (0.3230870520789363, 0.40383059674289123)      0.888020
# (0.40383059674289123, 0.4845741414068461)      0.942711
# (0.4845741414068461, 0.565317686070801)        0.973544
# (0.565317686070801, 0.646061230734756)         0.990531
# (0.646061230734756, 0.7268047753987109)        1.000000
#
#                                                                                   cdf_CI
# cut
# (0.00011287342311655124, 0.08085641808707149)  (0.1676750318945405, 0.16848495998521787)
# (0.08085641808707149, 0.16159996275102642)      (0.4325730917472098, 0.4342242907010565)
# (0.16159996275102642, 0.24234350741498134)      (0.6486394156687164, 0.6506460433122837)
# (0.24234350741498134, 0.3230870520789363)       (0.7953542117248474, 0.7972800114086444)
# (0.3230870520789363, 0.40383059674289123)       (0.8871821098323674, 0.8888569361163688)
# (0.40383059674289123, 0.4845741414068461)       (0.9420422844362523, 0.9433799312014836)
# (0.4845741414068461, 0.565317686070801)         (0.9730715803537732, 0.9740163219027455)
# (0.565317686070801, 0.646061230734756)           (0.990236645570878, 0.9908247456882093)
# (0.646061230734756, 0.7268047753987109)                                       (1.0, 1.0)

# %%
metrics(sim)
# Out:
#                                                                           Metrics
# Wait              Simulated                                              0.110944
#                   Confidence Interval  (0.11079179647966601, 0.11109589275941499)
#                   Analytical                                              0.11111
# Average Customers Simulated                                              0.111045
#                   Confidence Interval  (0.11084224346049502, 0.11124857138957149)
#                   Analytical                                              0.11111
# Utilization       Simulated                                              0.099829
#                   Confidence Interval   (0.09967245618335971, 0.0999858513366611)
#                   Analytical                                                  0.1

# %% [markdown]
# ## M/M/1: $\rho$ = 0.2, $\lambda$ = 1, $\mu$ = 2

# %%
sim = queue_sim(lamda = 1, mu = 2, max_events= 1e100)

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            1.006199
#                   Confidence Interval  (0.9502018520611715, 1.0621960848429535)
#                   Analytical                                            0.99707
# Average Customers Simulated                                            1.009646
#                   Confidence Interval    (0.9448982046191399, 1.07439303474755)
#                   Analytical                                            0.99707
# Utilization       Simulated                                            0.506599
#                   Confidence Interval   (0.4935535534396988, 0.519644259083084)
#                   Analytical                                           0.499878

# %%
sim.plot_customers()
# Out:
#          pdf                                            pdf_CI       cdf  \
# N
# 0   0.493401           (0.480355740916916, 0.5064464465603011)  0.493401
# 1   0.253783          (0.2464346374623067, 0.2611318249053272)  0.747184
# 2   0.129289        (0.12109127300915569, 0.13748635377624652)  0.876473
# 3   0.064249        (0.06090568173529125, 0.06759177809525986)  0.940722
# 4   0.029012        (0.02497184678799942, 0.03305123244671423)  0.969733
# 5   0.014006        (0.01106429912352834, 0.01694789116413897)  0.983740
# 6   0.007207     (0.0052060423109139406, 0.009208259316542563)  0.990947
# 7   0.003493      (0.002014700823734213, 0.004971576416366064)  0.994440
# 8   0.002919     (0.0012660137820318833, 0.004572945925824514)  0.996483
# 9   0.003800      (0.001402485388040428, 0.006197676096391439)  0.998763
# 10  0.001465   (-0.0001386918249047513, 0.0030693021877373355)  0.999643
# 11  0.001142        (0.0003098216067788, 0.001974497700728308)  0.999985
# 12  0.000073  (3.6737903286900204e-05, 0.00011018436245187135)  1.000000
#
#                                       cdf_CI
# N
# 0    (0.480355740916916, 0.5064464465603011)
# 1   (0.7345256206264013, 0.7598430292184497)
# 2   (0.8638735056378224, 0.8890727709924309)
# 3   (0.9301075152935031, 0.9513362211673012)
# 4   (0.9613898523673898, 0.9780769633281279)
# 5   (0.9773359057776494, 0.9901431002055359)
# 6   (0.9860472235499836, 0.9958460840606579)
# 7    (0.990214751366952, 0.9986648334837901)
# 8    (0.9933418198538735, 0.999625036792368)
# 9    (0.997314647178481, 1.0002123063584194)
# 10  (0.9992208048176319, 1.0000645149369682)
# 11  (0.9999654388337821, 1.0000051767130702)
# 12                                (1.0, 1.0)
# array([5.00061043e-01, 2.50030521e-01, 1.25015261e-01, 6.25076303e-02,
#        3.12538152e-02, 1.56269076e-02, 7.81345379e-03, 3.90672690e-03,
#        1.95336345e-03, 9.76681724e-04, 4.88340862e-04, 2.44170431e-04,
#        1.22085215e-04])
# array([0.50006104, 0.75009156, 0.87510682, 0.93761445, 0.96886827,
#        0.98449518, 0.99230863, 0.99621536, 0.99816872, 0.9991454 ,
#        0.99963374, 0.99987791, 1.        ])

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            1.006199
#                   Confidence Interval  (0.9502018520611715, 1.0621960848429535)
#                   Analytical                                            0.99707
# Average Customers Simulated                                            1.009646
#                   Confidence Interval    (0.9448982046191399, 1.07439303474755)
#                   Analytical                                            0.99707
# Utilization       Simulated                                            0.506599
#                   Confidence Interval   (0.4935535534396988, 0.519644259083084)
#                   Analytical                                           0.499878

# %% [markdown]
# ## M/M/1: $\rho$ = 1.2, $\lambda$ = 12, $\mu$ = 10

# %%
sim = queue_sim(lamda = 12, mu = 10, runs = 2000, max_events= 1e100)

# %%
sim.data
# Out:
#          type        time     N  run   holding
# 0           a    0.000000     1    0  0.068944
# 1           a    0.068944     2    0  0.069314
# 2           a    0.138258     3    0  0.016372
# 3           a    0.154630     4    0  0.120581
# 4           s    0.275210     3    0  0.058706
# ...       ...         ...   ...  ...       ...
# 21991818    a  999.853529  1946  999  0.054391
# 21991819    a  999.907919  1947  999  0.015767
# 21991820    s  999.923686  1946  999  0.001699
# 21991821    a  999.925385  1947  999  0.024561
# 21991822    a  999.949946  1948  999  0.080666
#
# [21991823 rows x 5 columns]

# %%
sim.plot_customers(max_ticks = 10)
# Out:
#            pdf                                            pdf_CI       cdf  \
# N
# 0     0.000490   (0.00045746634797441216, 0.0005234319090983682)  0.000490
# 1     0.000487    (0.0004571122864725348, 0.0005165436262582011)  0.000894
# 2     0.000483    (0.0004540132327637058, 0.0005113459849724988)  0.001377
# 3     0.000491     (0.000461795265973994, 0.0005201885884744575)  0.001868
# 4     0.000506    (0.0004749094138049939, 0.0005366892067798603)  0.002373
# ...        ...                                               ...       ...
# 2445  0.000289   (-0.00016549916343995037, 0.000743584659482135)  0.999987
# 2446  0.000393    (9.653267400823229e-05, 0.0006895330827152071)  0.999988
# 2447  0.000354   (0.0002236826437618616, 0.00048500713280564243)  0.999989
# 2448  0.000279   (-1.467229295697034e-05, 0.0005724913799917289)  0.999989
# 2449  0.000102  (-6.633547538600269e-05, 0.00027033825066730355)  0.999990
#
#                                                cdf_CI
# N
# 0     (0.00045746634797441216, 0.0005234319090983682)
# 1      (0.0008370861901403361, 0.0009507152759608074)
# 2       (0.001295135364775624, 0.0014580253190617245)
# 3      (0.0017624971172677893, 0.0019726474210180105)
# 4      (0.0022444948520739653, 0.0025022483067966886)
# ...                                               ...
# 2445         (0.9999640621246796, 1.0000107084583592)
# 2446         (0.9999659316005756, 1.0000104111139767)
# 2447         (0.9999674754348662, 1.0000102846592394)
# 2448         (0.9999688722788371, 1.0000100034534423)
# 2449         (0.9999694435132994, 1.0000098402245308)
#
# [2450 rows x 4 columns]

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                           83.627265
#                   Confidence Interval    (83.19674269973638, 84.05778770347567)
#                   Analytical                                                inf
# Average Customers Simulated                                         1003.471554
#                   Confidence Interval   (998.1548960468824, 1008.7882127740963)
#                   Analytical                                                inf
# Utilization       Simulated                                            0.999593
#                   Confidence Interval  (0.9995632883520282, 0.9996225660946014)
#                   Analytical                                                1.0

# %% [markdown]
# Os resultados não batem porque essa fila não entra em estado estacionário. Se aumentarmos a iterações máximas de eventos e tempo de simulação, iremos obter tamanhos máximos de fila cada vez maiores

# %% [markdown]
# ## M/M/1: $\rho$ = 2, $\lambda$ = 20, $\mu$ = 10

# %%
sim = queue_sim(lamda = 20, mu = 10, max_events= 1e100, runs = 100)

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                          250.210206
#                   Confidence Interval   (249.3670450988427, 251.05336672725906)
#                   Analytical                                                inf
# Average Customers Simulated                                         5001.253452
#                   Confidence Interval     (4984.36709133185, 5018.139812782821)
#                   Analytical                                                inf
# Utilization       Simulated                                             0.99996
#                   Confidence Interval  (0.9999451821518058, 0.9999740586632148)
#                   Analytical                                                1.0

# %%
sim.plot_customers(figsize=(20,5), max_ticks = 10)
# Out:
#             pdf                                            pdf_CI       cdf  \
# N
# 0      0.000084  (5.9283193003609156e-05, 0.00010896510903680619)  0.000084
# 1      0.000092   (7.631329995433512e-05, 0.00010733406686526174)  0.000132
# 2      0.000091   (7.509197199588901e-05, 0.00010655963043693742)  0.000223
# 3      0.000086   (7.081241981333434e-05, 0.00010120475201253005)  0.000309
# 4      0.000093   (7.637095758152251e-05, 0.00010971093298233153)  0.000402
# ...         ...                                               ...       ...
# 10329  0.000283  (0.00012831306153034003, 0.00043813085690855904)  0.999954
# 10330  0.000194  (-0.00015054959833507854, 0.0005383430228522411)  0.999957
# 10331  0.000209   (-0.0001592597611427138, 0.0005775511869724867)  0.999962
# 10332  0.000213  (-0.00016976493621047756, 0.0005951260437605469)  0.999966
# 10333  0.000323  (-0.00023488873426945507, 0.0008802579106619369)  0.999972
#
#                                                  cdf_CI
# N
# 0      (5.9283193003609156e-05, 0.00010896510903680619)
# 1      (0.00010591688467209445, 0.00015848966712690178)
# 2       (0.00018703868224371274, 0.0002590194719881099)
# 3       (0.00026793803695905177, 0.0003501372890986352)
# 4       (0.0003563872441815379, 0.00044776997244000313)
# ...                                                 ...
# 10329          (0.9998648080058795, 1.0000423360857706)
# 10330          (0.9998759130373123, 1.0000389869228283)
# 10331          (0.9998878596475439, 1.0000354061411134)
# 10332          (0.9999000851438276, 1.0000316878669808)
# 10333          (0.9999184035816455, 1.0000262768126904)
#
# [10334 rows x 4 columns]

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                          250.210206
#                   Confidence Interval   (249.3670450988427, 251.05336672725906)
#                   Analytical                                                inf
# Average Customers Simulated                                         5001.253452
#                   Confidence Interval     (4984.36709133185, 5018.139812782821)
#                   Analytical                                                inf
# Utilization       Simulated                                             0.99996
#                   Confidence Interval  (0.9999451821518058, 0.9999740586632148)
#                   Analytical                                                1.0
