# %%
#autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %load_ext autoreload
# %autoreload 2

# %%
from simulations import queue_sim
from simulated_metrics import customers_dist, metrics, wait_dist
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## M/M/1: $\rho$ = 0.1, $\lambda$ = 1, $\mu$ = 10

# %%
sim = queue_sim(lamda = 1, mu = 10, runs = 100)

# %%
sim.data
# Out:
#       type        time  N  run   holding
# 0        a    0.000000  1    0  0.008802
# 1        s    0.008802  0    0  0.508257
# 2        a    0.517059  1    0  0.178058
# 3        s    0.695117  0    0  0.361872
# 4        a    1.056989  1    0  0.081876
# ...    ...         ... ..  ...       ...
# 99895    a  546.054647  1   99  0.290480
# 99896    a  546.345127  2   99  0.032036
# 99897    s  546.377163  1   99  0.042758
# 99898    s  546.419921  0   99  0.030107
# 99899    a  546.450028  1   99  0.084117
#
# [99900 rows x 5 columns]

# %%
sim.service_durations
# Out:
# 1        0.008802
# 3        0.178058
# 5        0.081876
# 7        0.097175
# 9        0.087610
#            ...
# 99890    0.013446
# 99893    0.030400
# 99894    0.179503
# 99897    0.322516
# 99898    0.042758
# Name: duration, Length: 49899, dtype: float64

# %%
sim.plot_customers()
# Out:
#         pdf       cdf
# N
# 0  0.899753  0.899753
# 1  0.090525  0.990278
# 2  0.008740  0.999018
# 3  0.000883  0.999901
# 4  0.000097  0.999998
# 5  0.000002  1.000000

# %%
metrics(sim)
# Out:
#                                                                           Metrics
# Wait              Simulated                                              0.110676
#                   Confidence Interval   (0.1095818074047608, 0.11176986799710538)
#                   Analytical                                             0.111061
# Average Customers Simulated                                               0.11132
#                   Confidence Interval  (0.10978958183843932, 0.11284981917108938)
#                   Analytical                                             0.111061
# Utilization       Simulated                                              0.100448
#                   Confidence Interval    (0.099220839721175, 0.10167514991348371)
#                   Analytical                                             0.099991

# %% [markdown]
# ## M/M/1: $\rho$ = 0.2, $\lambda$ = 1, $\mu$ = 2

# %%
sim = queue_sim(lamda = 1, mu = 2)

# %%
metrics(sim)
# Out:
#                                                                           Metrics
# Wait              Simulated                                              0.961383
#                   Confidence Interval    (0.9083517797211642, 1.0144136234136734)
#                   Analytical                                              0.99707
# Average Customers Simulated                                              0.939514
#                   Confidence Interval     (0.888383076263759, 0.9906451809450947)
#                   Analytical                                              0.99707
# Utilization       Simulated                                              0.488508
#                   Confidence Interval  (0.48101524463735285, 0.49600000584036213)
#                   Analytical                                             0.499878

# %%
sim.plot_customers()
# Out:
#          pdf       cdf
# N
# 0   0.511610  0.511610
# 1   0.249493  0.761103
# 2   0.124127  0.885229
# 3   0.061065  0.946294
# 4   0.030618  0.976912
# 5   0.013270  0.990182
# 6   0.004723  0.994905
# 7   0.002838  0.997743
# 8   0.001014  0.998757
# 9   0.000486  0.999243
# 10  0.000333  0.999575
# 11  0.000359  0.999934
# 12  0.000066  1.000000

# %%
metrics(sim)
# Out:
#                                                                           Metrics
# Wait              Simulated                                              0.961383
#                   Confidence Interval    (0.9083517797211642, 1.0144136234136734)
#                   Analytical                                              0.99707
# Average Customers Simulated                                              0.939514
#                   Confidence Interval     (0.888383076263759, 0.9906451809450947)
#                   Analytical                                              0.99707
# Utilization       Simulated                                              0.488508
#                   Confidence Interval  (0.48101524463735285, 0.49600000584036213)
#                   Analytical                                             0.499878

# %% [markdown]
# ## M/M/1: $\rho$ = 1.2, $\lambda$ = 12, $\mu$ = 10

# %%
sim = queue_sim(lamda = 12, mu = 10, runs = 1000)

# %%
sim.plot_customers(xticks_dist = 10)
# Out:
#               pdf       cdf
# N
# 0    9.227660e-03  0.009228
# 1    1.130582e-02  0.020533
# 2    1.091035e-02  0.031444
# 3    1.083477e-02  0.042279
# 4    1.075983e-02  0.053038
# ..            ...       ...
# 197  9.452587e-07  0.999996
# 198  4.670603e-07  0.999996
# 199  5.813194e-07  0.999997
# 200  6.297240e-07  0.999997
# 201  2.681165e-06  1.000000
#
# [202 rows x 2 columns]

# %%
sim.data
# Out:
#        type       time    N  run   holding
# 0         a   0.000000    1    0  0.039033
# 1         a   0.039033    2    0  0.041397
# 2         a   0.080430    3    0  0.000679
# 3         a   0.081109    4    0  0.067263
# 4         a   0.148372    5    0  0.013874
# ...     ...        ...  ...  ...       ...
# 998995    a  44.410493  115  999  0.015847
# 998996    s  44.426340  114  999  0.136201
# 998997    a  44.562541  115  999  0.042677
# 998998    a  44.605218  116  999  0.099709
# 998999    a  44.704928  117  999  0.024184
#
# [999000 rows x 5 columns]

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            4.197292
#                   Confidence Interval    (4.116937898804203, 4.277645172943922)
#                   Analytical                                                inf
# Average Customers Simulated                                           50.492539
#                   Confidence Interval  (49.501938067879344, 51.483139839205585)
#                   Analytical                                                inf
# Utilization       Simulated                                            0.990611
#                   Confidence Interval  (0.9899360862476754, 0.9912859020992817)
#                   Analytical                                                1.0

# %% [markdown]
# Os resultados não batem porque essa fila não entra em estado estacionário. Se aumentarmos a iterações máximas de eventos e tempo de simulação, iremos obter tamanhos máximos de fila cada vez maiores

# %% [markdown]
# ## M/M/1: $\rho$ = 2, $\lambda$ = 20, $\mu$ = 10

# %%
sim = queue_sim(lamda = 20, mu = 10)
# Out:
# [autoreload of simulations failed: Traceback (most recent call last):
#   File "C:\Python38\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Python38\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "C:\Python38\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\gabri\Documents\trab-final-AD-2021.2\simulations.py", line 11, in <module>
#     from plot_metrics import plot_md1_customers_dist, plot_mm1_customers_dist
# ImportError: cannot import name 'plot_md1_customers_dist' from 'plot_metrics' (c:\Users\gabri\Documents\trab-final-AD-2021.2\plot_metrics.py)
# ]

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            8.570618
#                   Confidence Interval       (8.0808629041308, 9.06037389423409)
#                   Analytical                                                inf
# Average Customers Simulated                                          168.546664
#                   Confidence Interval   (159.7548310802799, 177.33849726232987)
#                   Analytical                                                inf
# Utilization       Simulated                                            0.998117
#                   Confidence Interval  (0.9968520616223897, 0.9993809677099466)
#                   Analytical                                                1.0

# %%
sim.plot()
# Out:
#           pdf       cdf
# N
# 0    0.000575  0.000575
# 1    0.003502  0.004077
# 2    0.005062  0.009139
# 3    0.004595  0.013734
# 4    0.003010  0.016743
# ..        ...       ...
# 373  0.000508  0.998826
# 374  0.000271  0.999097
# 375  0.000395  0.999493
# 376  0.000298  0.999790
# 377  0.000210  1.000000
#
# [378 rows x 2 columns]

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            8.584721
#                   Confidence Interval     (8.259810504715341, 8.90963095039555)
#                   Analytical                                                inf
# Average Customers Simulated                                          170.375373
#                   Confidence Interval   (165.47395060981907, 175.2767956032511)
#                   Analytical                                                inf
# Utilization       Simulated                                            0.999428
#                   Confidence Interval  (0.9985255667586288, 1.0003302996513717)
#                   Analytical                                                1.0
