# %%
#autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from simulations import queue_sim
from simulated_metrics import customers_dist, metrics, wait_dist
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## M/M/1: $\rho$ = 0.1, $\lambda$ = 1, $\mu$ = 10

# %%
sim = queue_sim(lamda = 1, mu = 10, runs = 100)

# %%
sim.data
# Out:
#       type        time    N  run   holding
# 0        a    0.000000    1    0  0.477740
# 1        a    0.477740    2    0  0.074474
# 2        a    0.552214    3    0  0.408362
# 3        a    0.960576    4    0  0.544992
# 4        a    1.505568    5    0  0.220720
# ...    ...         ...  ...  ...       ...
# 99895    a  326.903690  385   99  0.369882
# 99896    s  327.273572  384   99  0.100703
# 99897    a  327.374275  385   99  0.693170
# 99898    a  328.067445  386   99  0.773770
# 99899    a  328.841214  387   99  0.592360
#
# [99900 rows x 5 columns]

# %%
sim.service_durations
# Out:
# 9        3.094735
# 10       1.998492
# 14       1.153724
# 15       0.403058
# 18       1.109362
#            ...
# 99881    1.660305
# 99887    1.998501
# 99889    0.696967
# 99892    0.911024
# 99896    1.311484
# Name: duration, Length: 33193, dtype: float64

# %%
sim.plot_customers()
# Out:
#           pdf                                           pdf_CI       cdf  \
# N
# 0    0.002877     (0.002076579989587525, 0.003676642453271135)  0.002877
# 1    0.002986    (0.0023608375268266164, 0.003611163692753017)  0.004626
# 2    0.002841     (0.002197838366615015, 0.003484800151134353)  0.007467
# 3    0.003133     (0.002494898015595222, 0.003771716803058398)  0.010600
# 4    0.002917   (0.0023397969171998823, 0.0034933708254847227)  0.013517
# ..        ...                                              ...       ...
# 412  0.003516  (-0.00043212907388769225, 0.007464256227839458)  0.979134
# 413  0.002337   (0.0012198084382569296, 0.0034539791120787237)  0.981470
# 414  0.004339    (-0.001852126710167561, 0.010529170864022826)  0.985809
# 415  0.001226  (-0.0009804623186097366, 0.0034321240219662118)  0.987035
# 416  0.001961   (-0.0015979252806673197, 0.005520127435859383)  0.988996
#
#                                             cdf_CI
# N
# 0     (0.002076579989587525, 0.003676642453271135)
# 1    (0.0036128084881703634, 0.005638529523838705)
# 2    (0.0059925989890735835, 0.008941377540684851)
# 3        (0.0087390138197058, 0.01246157752870626)
# 4      (0.011342113073150112, 0.01569164601794655)
# ..                                             ...
# 412       (0.9613965397211707, 0.9968706679298741)
# 413       (0.9648505188332495, 0.9980904763681311)
# 414       (0.9629983921230819, 1.0086196472321538)
# 415         (0.9620179298044721, 1.01205177125412)
# 416        (0.9675380572403316, 1.010453845973453)
#
# [417 rows x 4 columns]

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                           83.474773
#                   Confidence Interval    (81.72221408939934, 85.22733214075747)
#                   Analytical                                                inf
# Average Customers Simulated                                          168.173089
#                   Confidence Interval    (164.6676106085921, 171.6785676912769)
#                   Analytical                                                inf
# Utilization       Simulated                                             0.99836
#                   Confidence Interval  (0.9978271636884729, 0.9988934995190976)
#                   Analytical                                                1.0

# %% [markdown]
# ## M/M/1: $\rho$ = 0.2, $\lambda$ = 1, $\mu$ = 2

# %%
sim = queue_sim(lamda = 1, mu = 2)

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            1.026831
#                   Confidence Interval  (0.9158701303130087, 1.1377925007044105)
#                   Analytical                                           0.999145
# Average Customers Simulated                                            1.038776
#                   Confidence Interval  (0.9072552833354874, 1.1702969329948758)
#                   Analytical                                           0.999145
# Utilization       Simulated                                            0.500797
#                   Confidence Interval  (0.4800840699071482, 0.5215104687217413)
#                   Analytical                                           0.499969

# %%
sim.plot_customers()
# Out:
#          pdf                                           pdf_CI       cdf  \
# N
# 0   0.499203         (0.4784895312782586, 0.5199159300928518)  0.499203
# 1   0.252479       (0.24754487540377135, 0.25741316241062095)  0.751682
# 2   0.117949       (0.11090970656361314, 0.12498740997738604)  0.869630
# 3   0.063939        (0.0551644008406671, 0.07271449177098718)  0.933570
# 4   0.029685      (0.025651243331110157, 0.03371971667642105)  0.963255
# 5   0.014371      (0.010568402321309466, 0.01817455098855041)  0.977627
# 6   0.008665     (0.006204766214550715, 0.011124560087338448)  0.986291
# 7   0.005416     (0.003292479859830628, 0.007540041529875767)  0.991708
# 8   0.003608    (0.0006549563525642945, 0.006560056601904401)  0.994394
# 9   0.004046  (-0.00026719007958135154, 0.008358381835034363)  0.993954
# 10  0.002887    (-0.000280994850601712, 0.006054542347852593)  0.995330
# 11  0.003592    (0.0004310511413164004, 0.006753242346070996)  0.997365
# 12  0.001634    (0.0008857552515645392, 0.002381576136878805)  0.997681
# 13  0.001884    (0.001475108638319302, 0.0022935420190096758)  0.999566
#
#                                       cdf_CI
# N
# 0   (0.4784895312782586, 0.5199159300928518)
# 1   (0.7280558019674336, 0.7753076972180689)
# 2   (0.8467858510348657, 0.8924747646916361)
# 3   (0.9169106147977022, 0.9502288935404539)
# 4    (0.9497133166739393, 0.976797151671748)
# 5   (0.9669597585294046, 0.9882936631261426)
# 6   (0.9768751871660648, 0.9957075607913719)
# 7   (0.9829706899752839, 1.0004445793718588)
# 8   (0.9877550916320795, 1.0010324428192143)
# 9    (0.987176748892475, 1.0007320048753072)
# 10  (0.9902903478934414, 1.0003691418135372)
# 11  (0.9947899144079537, 0.9999403653554049)
# 12  (0.9972437088556257, 0.9981190421778555)
# 13   (0.998718817493945, 1.0004125841968652)

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            1.026831
#                   Confidence Interval  (0.9158701303130087, 1.1377925007044105)
#                   Analytical                                           0.999145
# Average Customers Simulated                                            1.038776
#                   Confidence Interval  (0.9072552833354874, 1.1702969329948758)
#                   Analytical                                           0.999145
# Utilization       Simulated                                            0.500797
#                   Confidence Interval  (0.4800840699071482, 0.5215104687217413)
#                   Analytical                                           0.499969

# %% [markdown]
# ## M/M/1: $\rho$ = 1.2, $\lambda$ = 12, $\mu$ = 10

# %%
sim = queue_sim(lamda = 12, mu = 10, runs = 1000)

# %%
sim.data
# Out:
#        type       time   N  run   holding
# 0         a   0.000000   1    0  0.008296
# 1         s   0.008296   0    0  0.071245
# 2         a   0.079541   1    0  0.053966
# 3         s   0.133508   0    0  0.011847
# 4         a   0.145354   1    0  0.050743
# ...     ...        ...  ..  ...       ...
# 998995    s  46.148237  85  999  0.077899
# 998996    a  46.226135  86  999  0.072691
# 998997    a  46.298826  87  999  0.009217
# 998998    a  46.308043  88  999  0.045150
# 998999    a  46.353193  89  999  0.095854
#
# [999000 rows x 5 columns]

# %%
sim.plot_customers(xticks_dist = 10)
# Out:
#           pdf                                          pdf_CI       cdf  \
# N
# 0    0.011236    (0.010537376381700091, 0.011935486600010784)  0.011236
# 1    0.011384     (0.01071724518864351, 0.012049981185392487)  0.020744
# 2    0.011457    (0.010780891665852816, 0.012132684109945264)  0.032200
# 3    0.011404    (0.010722040933238173, 0.012086562560964402)  0.043605
# 4    0.011399     (0.010689786049333605, 0.01210810039268132)  0.055004
# ..        ...                                             ...       ...
# 181  0.006791     (0.003138600313967014, 0.01044427398024372)  0.989630
# 182  0.003507   (0.0008959180117242647, 0.006117738652974839)  0.993137
# 183  0.003192   (0.0014573533067950089, 0.004925788592153526)  0.996329
# 184  0.004859  (-0.0013813342972416025, 0.011099665466519353)  0.999352
# 185  0.000648  (-0.0004725829022189607, 0.001768421363629591)  1.000000
#
#                                            cdf_CI
# N
# 0    (0.010537376381700091, 0.011935486600010784)
# 1     (0.01949962970268599, 0.021987491535115172)
# 2    (0.030387283252783847, 0.034013413760815396)
# 3    (0.041248474832612694, 0.045960825675189124)
# 4     (0.05210513576273564, 0.057902051187081104)
# ..                                            ...
# 181      (0.9814615562694979, 0.9977988654130623)
# 182       (0.9867616717697312, 0.999512406577528)
# 183      (0.9916862294260578, 1.0009709908201503)
# 184       (0.9982315786363702, 1.000472582902219)
# 185      (0.9999999999999999, 1.0000000000000002)
#
# [186 rows x 4 columns]

# %%
metrics(sim)

# %% [markdown]
# Os resultados não batem porque essa fila não entra em estado estacionário. Se aumentarmos a iterações máximas de eventos e tempo de simulação, iremos obter tamanhos máximos de fila cada vez maiores

# %% [markdown]
# ## M/M/1: $\rho$ = 2, $\lambda$ = 20, $\mu$ = 10

# %%
sim = queue_sim(lamda = 20, mu = 10)

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            7.861787
#                   Confidence Interval    (7.541433266103784, 8.182141611324479)
#                   Analytical                                                inf
# Average Customers Simulated                                          158.453386
#                   Confidence Interval  (150.04006068737203, 166.86671100933665)
#                   Analytical                                                inf
# Utilization       Simulated                                            0.998893
#                   Confidence Interval   (0.9973014424023287, 1.000483604191356)
#                   Analytical                                                1.0

# %%
sim.plot_customers(figsize=(20,5), xticks_dist = 10)
# Out:
#           pdf       cdf
# N
# 0    0.001146  0.001146
# 1    0.003611  0.004757
# 2    0.003191  0.007948
# 3    0.003014  0.010962
# 4    0.002650  0.013612
# ..        ...       ...
# 351  0.000018  0.999233
# 352  0.000366  0.999599
# 353  0.000132  0.999731
# 354  0.000229  0.999960
# 355  0.000040  1.000000
#
# [356 rows x 2 columns]

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            7.861787
#                   Confidence Interval    (7.541433266103784, 8.182141611324479)
#                   Analytical                                                inf
# Average Customers Simulated                                          158.453386
#                   Confidence Interval  (150.04006068737203, 166.86671100933665)
#                   Analytical                                                inf
# Utilization       Simulated                                            0.998893
#                   Confidence Interval   (0.9973014424023287, 1.000483604191356)
#                   Analytical                                                1.0
