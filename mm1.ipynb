# %%
#autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %load_ext autoreload
# %autoreload 2

# %%
from simulations import queue_sim
from simulated_metrics import customers_dist, metrics, wait_dist
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## M/M/1: $\rho$ = 0.1, $\lambda$ = 1, $\mu$ = 10

# %%
sim = queue_sim(lamda = 1, mu = 10, runs = 3000, max_events = 1e100)

# %%
sim.data
# Out:
#         type        time  N   run   holding
# 0          a    0.000000  1     0  0.008242
# 1          s    0.008242  0     0  0.112363
# 2          a    0.120606  1     0  0.001471
# 3          s    0.122076  0     0  0.188550
# 4          a    0.310626  1     0  0.128525
# ...      ...         ... ..   ...       ...
# 6004352    a  997.758784  1  2999  0.079948
# 6004353    s  997.838732  0  2999  1.714450
# 6004354    a  999.553183  1  2999  0.084812
# 6004355    a  999.637995  2  2999  0.148235
# 6004356    s  999.786230  1  2999  0.281779
#
# [6004357 rows x 5 columns]

# %%
sim.plot_customers(figsize=(10,8))
# Out:
#         pdf                                            pdf_CI       cdf  \
# N
# 0  0.900073          (0.8999116832497468, 0.9002347121291873)  0.900073
# 1  0.089892        (0.08975560294754002, 0.09002802267800138)  0.989965
# 2  0.009030      (0.008979602115761562, 0.009079489803083584)  0.998995
# 3  0.000907    (0.0008914371444774543, 0.0009234761281306333)  0.999902
# 4  0.000160     (0.0001522375171833167, 0.000167162286830521)  0.999991
# 5  0.000124  (0.00010679526634992155, 0.00014020567017750148)  0.999999
# 6  0.000113   (7.365291950090908e-05, 0.00015184961691599286)  1.000000
# 7  0.000103  (3.8883384793873604e-05, 0.00016737385318762614)  1.000000
#
#                                      cdf_CI
# N
# 0  (0.8999116832497468, 0.9002347121291873)
# 1  (0.9899063635461354, 0.9900236574583401)
# 2  (0.9989759259541099, 0.9990131869692108)
# 3  (0.9998961759892215, 0.9999078502067071)
# 4  (0.9999894257533528, 0.9999929319998169)
# 5  (0.9999989269227957, 0.9999997328921847)
# 6  (0.9999998317411655, 1.0000000307540091)
# 7                                (1.0, 1.0)

# %%
sim.plot_wait(figsize = (10,8))
# Out:
#                                                    pdf  \
# cut
# (0.0001100272691300077, 0.08099748653375395)  0.168286
# (0.08099748653375395, 0.1618849457983779)     0.265335
# (0.1618849457983779, 0.24277240506300185)     0.215888
# (0.24277240506300185, 0.3236598643276258)     0.147565
# (0.3236598643276258, 0.4045473235922497)      0.091560
# (0.4045473235922497, 0.4854347828568737)      0.053852
# (0.4854347828568737, 0.5663222421214976)      0.030950
# (0.5663222421214976, 0.6472097013861215)      0.018070
# (0.6472097013861215, 0.7280971606507455)      0.012423
#
#                                                                                    pdf_CI  \
# cut
# (0.0001100272691300077, 0.08099748653375395)   (0.16787194823086257, 0.16869959939267262)
# (0.08099748653375395, 0.1618849457983779)        (0.2646926341480193, 0.2659775438519592)
# (0.1618849457983779, 0.24277240506300185)       (0.2152244483842065, 0.21655067349250984)
# (0.24277240506300185, 0.3236598643276258)       (0.14693177830905632, 0.1481980302581342)
# (0.3236598643276258, 0.4045473235922497)        (0.0909715239183451, 0.09214916406323297)
# (0.4045473235922497, 0.4854347828568737)       (0.05331147800699513, 0.05439153667186541)
# (0.4854347828568737, 0.5663222421214976)       (0.0305105024017647, 0.031389477449087835)
# (0.5663222421214976, 0.6472097013861215)       (0.0177273064389335, 0.018413131523484456)
# (0.6472097013861215, 0.7280971606507455)      (0.01213758661122942, 0.012707865571295534)
#
#                                                    cdf  \
# cut
# (0.0001100272691300077, 0.08099748653375395)  0.168286
# (0.08099748653375395, 0.1618849457983779)     0.433621
# (0.1618849457983779, 0.24277240506300185)     0.649508
# (0.24277240506300185, 0.3236598643276258)     0.797073
# (0.3236598643276258, 0.4045473235922497)      0.888634
# (0.4045473235922497, 0.4854347828568737)      0.942485
# (0.4854347828568737, 0.5663222421214976)      0.973389
# (0.5663222421214976, 0.6472097013861215)      0.990484
# (0.6472097013861215, 0.7280971606507455)      1.000000
#
#                                                                                   cdf_CI
# cut
# (0.0001100272691300077, 0.08099748653375395)  (0.16787194823086257, 0.16869959939267262)
# (0.08099748653375395, 0.1618849457983779)      (0.43277205813471875, 0.4344696674887949)
# (0.1618849457983779, 0.24277240506300185)       (0.6484966741472243, 0.6505201733530058)
# (0.24277240506300185, 0.3236598643276258)       (0.7961050930048083, 0.7980415630626122)
# (0.3236598643276258, 0.4045473235922497)        (0.8877791312665563, 0.8894882127824423)
# (0.4045473235922497, 0.4854347828568737)        (0.9418189572892629, 0.9431514014385961)
# (0.4854347828568737, 0.5663222421214976)        (0.9729151379716855, 0.9738630476822542)
# (0.5663222421214976, 0.6472097013861215)        (0.9901900533562946, 0.9907779947442863)
# (0.6472097013861215, 0.7280971606507455)                                      (1.0, 1.0)

# %%
metrics(sim)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\aluno08.TSACBRRJLP044\Documents\GitHub\trab-final-AD-2021.2\mm1.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/mm1.ipynb#ch0000006?line=0'>1</a> metrics(sim)
#
# File c:\Users\aluno08.TSACBRRJLP044\Documents\GitHub\trab-final-AD-2021.2\simulated_metrics.py:110, in metrics(simulation_obj)
#     <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/simulated_metrics.py?line=108'>109</a> def metrics(simulation_obj : Simulation):
# --> <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/simulated_metrics.py?line=109'>110</a>   _wait_metrics = wait_metric(simulation_obj)
#     <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/simulated_metrics.py?line=110'>111</a>   _customers_metrics = customers_metrics(simulation_obj)
#     <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/simulated_metrics.py?line=111'>112</a>   _utilization_metric = utilization(simulation_obj)
#
# File c:\Users\aluno08.TSACBRRJLP044\Documents\GitHub\trab-final-AD-2021.2\simulated_metrics.py:72, in wait_metric(simulation_obj)
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/simulated_metrics.py?line=66'>67</a> means = {
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/simulated_metrics.py?line=67'>68</a>   #'delay':[],
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/simulated_metrics.py?line=68'>69</a>   'wait' : []
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/simulated_metrics.py?line=69'>70</a> }
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/simulated_metrics.py?line=70'>71</a> for idx, services in services_by_run:
# ---> <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/simulated_metrics.py?line=71'>72</a>   services = services.reset_index()[['time', 'duration']]
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/simulated_metrics.py?line=72'>73</a>   services_count = services.shape[0]
#      <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/Documents/GitHub/trab-final-AD-2021.2/simulated_metrics.py?line=73'>74</a>   corresponding_arrivals = arrivals_by_run.get_group(idx).head(services_count).reset_index().time
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3508'>3509</a>     if is_iterator(key):
#    <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3509'>3510</a>         key = list(key)
# -> <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3510'>3511</a>     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3512'>3513</a> # take() does not accept boolean indexers
#    <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3513'>3514</a> if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5778'>5779</a> else:
#    <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5779'>5780</a>     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5781'>5782</a> self._raise_if_missing(keyarr, indexer, axis_name)
#    <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5783'>5784</a> keyarr = self.take(indexer)
#    <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5784'>5785</a> if isinstance(key, Index):
#    <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5785'>5786</a>     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5841'>5842</a>     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5843'>5844</a> not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> <a href='file:///c%3A/Users/aluno08.TSACBRRJLP044/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5844'>5845</a> raise KeyError(f"{not_found} not in index")
#
# KeyError: "['duration'] not in index"

# %% [markdown]
# ## M/M/1: $\rho$ = 0.2, $\lambda$ = 1, $\mu$ = 2

# %%
sim = queue_sim(lamda = 1, mu = 2, max_events= 1e100)

# %%
metrics(sim)
# Out:
#                                                                          Metrics
# Wait              Simulated                                             0.947616
#                   Confidence Interval    (0.9047067672340403, 0.990526220314234)
#                   Analytical                                            0.998413
# Average Customers Simulated                                             0.933802
#                   Confidence Interval   (0.8887778328749615, 0.9788269137434312)
#                   Analytical                                            0.998413
# Utilization       Simulated                                             0.485533
#                   Confidence Interval  (0.4741155931357469, 0.49695021544150453)
#                   Analytical                                            0.499939

# %%
sim.plot_customers()
# Out:
#          pdf                                           pdf_CI       cdf  \
# N
# 0   0.514467          (0.5030497845584954, 0.525884406864253)  0.514467
# 1   0.254128        (0.24806999242002978, 0.2601860316979815)  0.768595
# 2   0.121722        (0.11635379333930666, 0.1270893688227429)  0.890317
# 3   0.057221      (0.052994331670786245, 0.06144788014477153)  0.947538
# 4   0.024899      (0.02158044247463164, 0.028216756398379474)  0.972436
# 5   0.013936      (0.011771545967050092, 0.01609964275499503)  0.986372
# 6   0.006695     (0.005195658776865715, 0.008193450338461604)  0.993067
# 7   0.004225    (0.0026485161157892064, 0.005801138092999637)  0.997291
# 8   0.002219   (0.0012341593884191288, 0.0032043034322004112)  0.999067
# 9   0.000726  (0.00022004534960865115, 0.0012326496756338138)  0.999503
# 10  0.000558  (-0.0005011978729854447, 0.0016171336640470313)  0.999614
#
#                                       cdf_CI
# N
# 0    (0.5030497845584954, 0.525884406864253)
# 1   (0.7581645310134636, 0.7790256845272961)
# 2   (0.8825021960712232, 0.8981311816315862)
# 3   (0.9404894542672545, 0.9545861352511124)
# 4   (0.9669891762919505, 0.9778836120994279)
# 5   (0.9821922025999817, 0.9905517745134415)
# 6   (0.9898254010075874, 0.9963076852211631)
# 7   (0.9954132391878346, 0.9991695012497049)
# 8    (0.9978670856957921, 1.000266424998243)
# 9   (0.9985357670719017, 1.0004693606372788)
# 10  (0.9988617644294043, 1.0003665504379882)

# %%
metrics(sim)
# Out:
#                                                                          Metrics
# Wait              Simulated                                             0.947616
#                   Confidence Interval    (0.9047067672340403, 0.990526220314234)
#                   Analytical                                            0.998413
# Average Customers Simulated                                             0.933802
#                   Confidence Interval   (0.8887778328749615, 0.9788269137434312)
#                   Analytical                                            0.998413
# Utilization       Simulated                                             0.485533
#                   Confidence Interval  (0.4741155931357469, 0.49695021544150453)
#                   Analytical                                            0.499939

# %% [markdown]
# ## M/M/1: $\rho$ = 1.2, $\lambda$ = 12, $\mu$ = 10

# %%
sim = queue_sim(lamda = 12, mu = 10, runs = int(1e10), max_events= 1e100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\gabri\Documents\trab-final-AD-2021.2\mm1.ipynb Cell 15' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gabri/Documents/trab-final-AD-2021.2/mm1.ipynb#ch0000014?line=0'>1</a> sim = queue_sim(lamda = 12, mu = 10, runs = int(1e100), max_events= 1e100)
#
# File c:\Users\gabri\Documents\trab-final-AD-2021.2\simulations.py:215, in queue_sim(lamda, mu, max_time, max_events, runs, kind, export)
#     <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=211'>212</a> ledger_df = []
#     <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=213'>214</a> for i in range(runs):
# --> <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=214'>215</a>     ledger = m_queue(lamda, mu, max_time = max_time, max_events = max_events, kind = kind)
#     <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=215'>216</a>     ledger = pd.DataFrame(ledger)
#     <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=216'>217</a>     ledger['run'] = i
#
# File c:\Users\gabri\Documents\trab-final-AD-2021.2\simulations.py:189, in m_queue(lamda, mu, max_time, max_events, kind)
#     <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=186'>187</a>   if(N == 1):
#     <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=187'>188</a>     schedule_service()
# --> <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=188'>189</a>   schedule_arrival()
#     <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=189'>190</a>   equeue = sorted(equeue, key = lambda x : x['time'])
#     <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=190'>191</a> else:
#
# File c:\Users\gabri\Documents\trab-final-AD-2021.2\simulations.py:173, in m_queue.<locals>.schedule_arrival()
#     <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=169'>170</a> def schedule_arrival():
#     <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=170'>171</a>   equeue.append({
#     <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=171'>172</a>     'type' : 'a',
# --> <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=172'>173</a>     'time' : time +  np.random.exponential(1/lamda),
#     <a href='file:///c%3A/Users/gabri/Documents/trab-final-AD-2021.2/simulations.py?line=173'>174</a>     })
#
# KeyboardInterrupt:

# %%
sim.data
# Out:
#          type        time     N  run   holding
# 0           a    0.000000     1    0  0.068944
# 1           a    0.068944     2    0  0.069314
# 2           a    0.138258     3    0  0.016372
# 3           a    0.154630     4    0  0.120581
# 4           s    0.275210     3    0  0.058706
# ...       ...         ...   ...  ...       ...
# 21991818    a  999.853529  1946  999  0.054391
# 21991819    a  999.907919  1947  999  0.015767
# 21991820    s  999.923686  1946  999  0.001699
# 21991821    a  999.925385  1947  999  0.024561
# 21991822    a  999.949946  1948  999  0.080666
#
# [21991823 rows x 5 columns]

# %%
sim.plot_customers(max_ticks = 10)
# Out:
#            pdf                                            pdf_CI       cdf  \
# N
# 0     0.000490   (0.00045746634797441216, 0.0005234319090983682)  0.000490
# 1     0.000487    (0.0004571122864725348, 0.0005165436262582011)  0.000894
# 2     0.000483    (0.0004540132327637058, 0.0005113459849724988)  0.001377
# 3     0.000491     (0.000461795265973994, 0.0005201885884744575)  0.001868
# 4     0.000506    (0.0004749094138049939, 0.0005366892067798603)  0.002373
# ...        ...                                               ...       ...
# 2445  0.000289   (-0.00016549916343995037, 0.000743584659482135)  0.999987
# 2446  0.000393    (9.653267400823229e-05, 0.0006895330827152071)  0.999988
# 2447  0.000354   (0.0002236826437618616, 0.00048500713280564243)  0.999989
# 2448  0.000279   (-1.467229295697034e-05, 0.0005724913799917289)  0.999989
# 2449  0.000102  (-6.633547538600269e-05, 0.00027033825066730355)  0.999990
#
#                                                cdf_CI
# N
# 0     (0.00045746634797441216, 0.0005234319090983682)
# 1      (0.0008370861901403361, 0.0009507152759608074)
# 2       (0.001295135364775624, 0.0014580253190617245)
# 3      (0.0017624971172677893, 0.0019726474210180105)
# 4      (0.0022444948520739653, 0.0025022483067966886)
# ...                                               ...
# 2445         (0.9999640621246796, 1.0000107084583592)
# 2446         (0.9999659316005756, 1.0000104111139767)
# 2447         (0.9999674754348662, 1.0000102846592394)
# 2448         (0.9999688722788371, 1.0000100034534423)
# 2449         (0.9999694435132994, 1.0000098402245308)
#
# [2450 rows x 4 columns]

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                           83.627265
#                   Confidence Interval    (83.19674269973638, 84.05778770347567)
#                   Analytical                                                inf
# Average Customers Simulated                                         1003.471554
#                   Confidence Interval   (998.1548960468824, 1008.7882127740963)
#                   Analytical                                                inf
# Utilization       Simulated                                            0.999593
#                   Confidence Interval  (0.9995632883520282, 0.9996225660946014)
#                   Analytical                                                1.0

# %% [markdown]
# Os resultados não batem porque essa fila não entra em estado estacionário. Se aumentarmos a iterações máximas de eventos e tempo de simulação, iremos obter tamanhos máximos de fila cada vez maiores

# %% [markdown]
# ## M/M/1: $\rho$ = 2, $\lambda$ = 20, $\mu$ = 10

# %%
sim = queue_sim(lamda = 20, mu = 10, max_events= 1e100, runs = 100)

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                          250.210206
#                   Confidence Interval   (249.3670450988427, 251.05336672725906)
#                   Analytical                                                inf
# Average Customers Simulated                                         5001.253452
#                   Confidence Interval     (4984.36709133185, 5018.139812782821)
#                   Analytical                                                inf
# Utilization       Simulated                                             0.99996
#                   Confidence Interval  (0.9999451821518058, 0.9999740586632148)
#                   Analytical                                                1.0

# %%
sim.plot_customers(figsize=(20,5), max_ticks = 10)
# Out:
#             pdf                                            pdf_CI       cdf  \
# N
# 0      0.000084  (5.9283193003609156e-05, 0.00010896510903680619)  0.000084
# 1      0.000092   (7.631329995433512e-05, 0.00010733406686526174)  0.000132
# 2      0.000091   (7.509197199588901e-05, 0.00010655963043693742)  0.000223
# 3      0.000086   (7.081241981333434e-05, 0.00010120475201253005)  0.000309
# 4      0.000093   (7.637095758152251e-05, 0.00010971093298233153)  0.000402
# ...         ...                                               ...       ...
# 10329  0.000283  (0.00012831306153034003, 0.00043813085690855904)  0.999954
# 10330  0.000194  (-0.00015054959833507854, 0.0005383430228522411)  0.999957
# 10331  0.000209   (-0.0001592597611427138, 0.0005775511869724867)  0.999962
# 10332  0.000213  (-0.00016976493621047756, 0.0005951260437605469)  0.999966
# 10333  0.000323  (-0.00023488873426945507, 0.0008802579106619369)  0.999972
#
#                                                  cdf_CI
# N
# 0      (5.9283193003609156e-05, 0.00010896510903680619)
# 1      (0.00010591688467209445, 0.00015848966712690178)
# 2       (0.00018703868224371274, 0.0002590194719881099)
# 3       (0.00026793803695905177, 0.0003501372890986352)
# 4       (0.0003563872441815379, 0.00044776997244000313)
# ...                                                 ...
# 10329          (0.9998648080058795, 1.0000423360857706)
# 10330          (0.9998759130373123, 1.0000389869228283)
# 10331          (0.9998878596475439, 1.0000354061411134)
# 10332          (0.9999000851438276, 1.0000316878669808)
# 10333          (0.9999184035816455, 1.0000262768126904)
#
# [10334 rows x 4 columns]

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                          250.210206
#                   Confidence Interval   (249.3670450988427, 251.05336672725906)
#                   Analytical                                                inf
# Average Customers Simulated                                         5001.253452
#                   Confidence Interval     (4984.36709133185, 5018.139812782821)
#                   Analytical                                                inf
# Utilization       Simulated                                             0.99996
#                   Confidence Interval  (0.9999451821518058, 0.9999740586632148)
#                   Analytical                                                1.0
