# %%
#autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %load_ext autoreload
# %autoreload 2

# %%
from mmk import queue_sim, m_queue
import pandas as pd
from simulated_metrics import metrics

# %%
pd.set_option("display.max_rows", 100)

# %%
sim = queue_sim(1,10 ,3, runs = 2000, max_events= 1e100)

# %%
sim.plot_customers(figsize = (10,8), max_ticks = 50)
# Out:
#         pdf                                            pdf_CI       cdf  \
# N
# 0  0.904876          (0.9046988587268058, 0.9050532404389126)  0.904876
# 1  0.090442        (0.09027570470668461, 0.09060770491157213)  0.995318
# 2  0.004525       (0.004494214455445303, 0.00455582729656848)  0.999843
# 3  0.000154   (0.0001492582799079804, 0.00015828519420471452)  0.999995
# 4  0.000036  (3.2160390481087586e-05, 4.0043261730069213e-05)  1.000000
# 5  0.000043   (1.9873505708702498e-05, 6.703159256224964e-05)  1.000000
#
#                                      cdf_CI
# N
# 0  (0.9046988587268058, 0.9050532404389126)
# 1   (0.9952855585329361, 0.995349950251039)
# 2  (0.9998380563203175, 0.9998474942156714)
# 3  (0.9999937053203493, 0.9999953906245888)
# 4  (0.9999996084278168, 0.9999999570466919)
# 5                                (1.0, 1.0)
# [[ -1.   1.   0.   0.   0.   0.]
#  [ 10. -11.   1.   0.   0.   0.]
#  [  0.  20. -21.   1.   0.   0.]
#  [  0.   0.  30. -31.   1.   0.]
# ...

# %%
sim.plot_wait(figsize = (10,8))
# Out:
#                                                     cdf  \
# cut
# (0.00010839542181932844, 0.06950684917232566)  0.154907
# (0.06950684917232566, 0.138905302922832)       0.420571
# (0.138905302922832, 0.20830375667333834)       0.645688
# (0.20830375667333834, 0.2777022104238447)      0.797851
# (0.2777022104238447, 0.34710066417435104)      0.891683
# (0.34710066417435104, 0.41649911792485733)     0.945280
# (0.41649911792485733, 0.4858975716753637)      0.975170
# (0.4858975716753637, 0.55529602542587)         0.991290
# (0.55529602542587, 0.6246944791763763)         1.000000
#
#                                                                                    cdf_CI
# cut
# (0.00010839542181932844, 0.06950684917232566)  (0.15446441622506651, 0.15534923527223649)
# (0.06950684917232566, 0.138905302922832)         (0.4196683597841935, 0.4214733443147689)
# (0.138905302922832, 0.20830375667333834)         (0.6445982082124961, 0.6467776804089749)
# ...

# %%
metrics(sim)
# Out:
#                                                                           Metrics
# Wait              Simulated                                              0.100037
#                   Confidence Interval   (0.0998975051461679, 0.10017618075394981)
#                   Analytical                                             0.100005
# Average Customers Simulated                                              0.100145
#                   Confidence Interval  (0.09995097150627534, 0.10033951435062631)
#                   Analytical                                             0.100005
# Utilization       Simulated                                              0.095124
#                   Confidence Interval   (0.09494675956108753, 0.0953011412731942)
#                   Analytical                                             0.095164

# %%
sim = queue_sim(2,3, 10, max_events= 1e100, runs = 2000)

# %%
sim.plot_customers(figsize = (10,8), max_ticks = 50)
# Out:
#         pdf                                            pdf_CI       cdf  \
# N
# 0  0.513597          (0.5130845523491315, 0.5141087273641581)  0.513597
# 1  0.342029          (0.3416691103300865, 0.3423886061405367)  0.855625
# 2  0.114100        (0.11384363917503539, 0.11435574081688406)  0.969725
# 3  0.025387       (0.025272829008663403, 0.02550077504882192)  0.995112
# 4  0.004237       (0.004196132400947142, 0.00427859227947946)  0.999349
# 5  0.000576    (0.0005626152827955252, 0.0005901067308224506)  0.999925
# 6  0.000108   (0.00010235394474114553, 0.0001135442893048155)  0.999993
# 7  0.000055    (4.768180907267904e-05, 6.287692419497296e-05)  0.999999
# 8  0.000048   (2.8786020440980684e-05, 6.631758939648567e-05)  1.000000
# 9  0.000051  (-2.488605083092733e-05, 0.00012650072151864074)  1.000000
#
#                                      cdf_CI
# N
# 0  (0.5130845523491315, 0.5141087273641581)
# 1  (0.8552853136435756, 0.8559656825403372)
# ...

# %%
sim.plot_wait(figsize = (10,8))
# Out:
#                                                   cdf  \
# cut
# (0.00031101975831478737, 0.187814856161473)  0.098745
# (0.187814856161473, 0.3753186925646312)      0.355105
# (0.3753186925646312, 0.5628225289677894)     0.618038
# (0.5628225289677894, 0.7503263653709477)     0.801060
# (0.7503263653709477, 0.9378302017741059)     0.905216
# (0.9378302017741059, 1.1253340381772639)     0.958371
# (1.1253340381772639, 1.3128378745804221)     0.983489
# (1.3128378745804221, 1.5003417109835804)     0.994853
# (1.5003417109835804, 1.6878455473867386)     1.000000
#
#                                                                                  cdf_CI
# cut
# (0.00031101975831478737, 0.187814856161473)  (0.09849691506278278, 0.09899259087160446)
# (0.187814856161473, 0.3753186925646312)      (0.35449068069684697, 0.35572012454736823)
# (0.3753186925646312, 0.5628225289677894)       (0.6172545645268311, 0.6188205741639062)
# ...

# %%
metrics(sim)
# Out:
#                                                                           Metrics
# Wait              Simulated                                              0.332958
#                   Confidence Interval  (0.33263877145521015, 0.33327656687005813)
#                   Analytical                                             0.333333
# Average Customers Simulated                                              0.667127
#                   Confidence Interval    (0.6662160324196605, 0.6680382685421383)
#                   Analytical                                             0.666667
# Utilization       Simulated                                              0.486403
#                   Confidence Interval  (0.48589127263584186, 0.48691544765086847)
#                   Analytical                                             0.486583

# %%
sim = queue_sim(10, 2, 100, max_events= 1e100, runs = 2000)

# %%
sim.plot_customers(figsize = (10,8), max_ticks = 50)
# Out:
#          pdf                                            pdf_CI       cdf  \
# N
# 0   0.006780     (0.0067221255021005875, 0.006838077323813569)  0.006780
# 1   0.033905        (0.03376619330060564, 0.03404344291333307)  0.040685
# 2   0.084491        (0.08427873012137202, 0.08470390749024903)  0.125176
# 3   0.140564        (0.14033072667593702, 0.14079749259306748)  0.265740
# 4   0.175523        (0.17531274900673915, 0.17573382895929007)  0.441264
# 5   0.175417         (0.1752200802617098, 0.17561481417305277)  0.616681
# 6   0.146036         (0.1458417458212581, 0.14623018714374444)  0.762717
# 7   0.104241        (0.10405677521235357, 0.10442500298079863)  0.866958
# 8   0.065190        (0.06503892183177654, 0.06534039662624425)  0.932148
# 9   0.036149      (0.036033063294762316, 0.036264964159664265)  0.968297
# 10  0.018083       (0.01800185909178327, 0.018164670122479395)  0.986380
# 11  0.008198      (0.008146351559617912, 0.008250430772309811)  0.994578
# ...

# %%
sim.plot_wait(figsize = (10,8))
# Out:
#                                                    cdf  \
# cut
# (0.0064118394668606854, 0.14838501024493278)  0.003375
# (0.14838501024493278, 0.29035818102300487)    0.053738
# (0.29035818102300487, 0.43233135180107696)    0.244080
# (0.43233135180107696, 0.574304522579149)      0.542883
# (0.574304522579149, 0.716277693357221)        0.794725
# (0.716277693357221, 0.8582508641352932)       0.928999
# (0.8582508641352932, 1.0002240349133653)      0.980587
# (1.0002240349133653, 1.1421972056914373)      0.996085
# (1.1421972056914373, 1.2841703764695094)      1.000000
#
#                                                                                       cdf_CI
# cut
# (0.0064118394668606854, 0.14838501024493278)  (0.0033574034150663135, 0.0033931759261892932)
# (0.14838501024493278, 0.29035818102300487)        (0.05359788182757716, 0.05387784884186113)
# (0.29035818102300487, 0.43233135180107696)          (0.24369486966156667, 0.244464833060675)
# ...

# %%
metrics(sim)
# Out:
#                                                                          Metrics
# Wait              Simulated                                             0.499693
#                   Confidence Interval  (0.49947358090379035, 0.4999119449265853)
#                   Analytical                                                 0.5
# Average Customers Simulated                                             4.996131
#                   Confidence Interval     (4.993102567235546, 4.999159872643066)
#                   Analytical                                                 5.0
# Utilization       Simulated                                              0.99322
#                   Confidence Interval   (0.9931619226761864, 0.9932778744978995)
#                   Analytical                                            0.993262

# %%
sim = queue_sim(20,2, 10, max_events= 1e100, runs = 2000)

# %%
sim.plot_customers(figsize = (10,8), max_ticks = 50)
# Out:
#           pdf                                            pdf_CI       cdf  \
# N
# 0    0.000062    (5.4778500141136456e-05, 6.83233406773224e-05)  0.000062
# 1    0.000096     (9.175104063897826e-05, 9.97014060382489e-05)  0.000107
# 2    0.000226  (0.00021696608613899605, 0.00023449242513034365)  0.000332
# 3    0.000579    (0.0005578194862403989, 0.0006000203699278211)  0.000911
# 4    0.001315    (0.0012696837452110914, 0.0013600807683102874)  0.002226
# ..        ...                                               ...       ...
# 679  0.000214   (-0.0001798353826264658, 0.0006076533561973273)  0.999996
# 680  0.000241  (-0.00014452022266087921, 0.0006263926753915012)  0.999996
# 681  0.000307  (-0.00015849050986352397, 0.0007734659721141186)  0.999997
# 682  0.000302   (-8.006885520120633e-05, 0.0006838802699003586)  0.999997
# 683  0.000307  (-0.00023819735911571362, 0.0008514653229767008)  0.999997
#
#                                                cdf_CI
# N
# ...

# %%
metrics(sim)
# Out:
#                                                                         Metrics
# Wait              Simulated                                            5.619182
#                   Confidence Interval    (5.485332518158119, 5.753031142803534)
#                   Analytical                                          25.133421
# Average Customers Simulated                                          112.479408
#                   Confidence Interval   (109.7868494362704, 115.17196629806848)
#                   Analytical                                         502.668411
# Utilization       Simulated                                            0.999989
#                   Confidence Interval  (0.9999876318837929, 0.9999907637431434)
#                   Analytical                                                1.0
